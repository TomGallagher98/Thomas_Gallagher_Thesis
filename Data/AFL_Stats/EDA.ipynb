# %%
print("Activating ipynb")
print ("Importing libs")
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# Out:
# Activating ipynb
# Importing libs

# %%
# Load Initial Data
print("Loading Initial Game Data")
games_folder_path = "C:/Users/Craig/Documents/Thesis/Thomas_Gallagher_Thesis/Data/AFL_Stats_sorted/Year/Games/"
games_raw_2012 = pd.read_csv(games_folder_path + '2012.csv', index_col=False,dayfirst=True, parse_dates=['date'])
games_raw_2013 = pd.read_csv(games_folder_path + '2013.csv', index_col=False, parse_dates=['date'], dayfirst=True)
games_raw_2014 = pd.read_csv(games_folder_path + '2014.csv', index_col=False, parse_dates=['date'], dayfirst=True)
games_raw_2015 = pd.read_csv(games_folder_path + '2015.csv', index_col=False, parse_dates=['date'], dayfirst=True)
games_raw_2016 = pd.read_csv(games_folder_path + '2016.csv', index_col=False, parse_dates=['date'], dayfirst=True)
games_raw_2017 = pd.read_csv(games_folder_path + '2017.csv', index_col=False, parse_dates=['date'], dayfirst=True)
games_raw_2018 = pd.read_csv(games_folder_path + '2018.csv', index_col=False, parse_dates=['date'], dayfirst=True)
games_raw_2019 = pd.read_csv(games_folder_path + '2019.csv', index_col=False, parse_dates=['date'], dayfirst=True)
games_raw_2020 = pd.read_csv(games_folder_path + '2020.csv', index_col=False, parse_dates=['date'], dayfirst=True)
games_raw_2021 = pd.read_csv(games_folder_path + '2021.csv', index_col=False, parse_dates=['date'], dayfirst=True)

all_games = os.path.join("C:/Users/Craig/Documents/Thesis/Thomas_Gallagher_Thesis/Data/AFL_Stats_sorted/games_sorted.csv")
all_games_raw = pd.read_csv(all_games, index_col=False, parse_dates=['date'], dayfirst=True)
# Out:
# Loading Initial Game Data

# %%
games_raw_2012.corr()
# Out:
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13972\2836803515.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   games_raw_2012.corr()
#                                  year     round  attendance  homeTeamScore  \
# year                              NaN       NaN         NaN            NaN
# round                             NaN  1.000000    0.036172       0.047039
# attendance                        NaN  0.036172    1.000000       0.043709
# homeTeamScore                     NaN  0.047039    0.043709       1.000000
# awayTeamScore                     NaN  0.019936    0.045352      -0.437422
# rainfall                          NaN -0.036310    0.033078      -0.012509
# homeWin                           NaN -0.007892    0.053480       0.685309
# homeTeamLastWin                   NaN  0.103898    0.271107       0.053632
# awayTeamLastWin                   NaN  0.123067    0.180365      -0.067623
# awayTravel                        NaN  0.028575   -0.321810      -0.072739
# homeTravel                        NaN -0.021027   -0.211053       0.076807
# homeTeamChanges                   NaN  0.216110   -0.248327      -0.093229
# awayTeamChanges                   NaN  0.157481   -0.189398       0.153723
# homeGameDifference                NaN -0.046907   -0.043537       0.160139
# awayGameDifference                NaN  0.018026   -0.173298       0.118514
# homeTeamImportanceDifference      NaN  0.120468   -0.115341       0.119138
# awayTeamImportanceDifference      NaN  0.148033   -0.158438      -0.095780
# homeTeamImportanceLastGame        NaN  0.118710   -0.117569       0.126039
# awayTeamImportanceLastGame        NaN  0.237067   -0.071730       0.006612
# homeTeamImportanceLastFiveGames   NaN  0.270548   -0.005548       0.134078
# awayTeamImportanceLastFiveGames   NaN  0.313341    0.008743      -0.034791
# homeTeamImportanceSeasonAverage   NaN  0.306971    0.056751       0.130423
# awayTeamImportanceSeasonAverage   NaN  0.317790    0.035819      -0.068694
# homeLadderPosition                NaN -0.074377   -0.502454      -0.347530
# awayLadderPosition                NaN -0.013582   -0.412762       0.315902
# homeTeamPointsFor                 NaN  0.946386    0.182790       0.166833
# homeTeamPointsAgainst             NaN  0.962141   -0.085959      -0.030124
# homeTeamPercentage                NaN  0.154306    0.288828       0.302600
# awayTeamPointsFor                 NaN  0.950499    0.116121      -0.065772
# awayTeamPointsAgainst             NaN  0.962174   -0.040166       0.154170
# awayTeamPercentage                NaN  0.229212    0.122881      -0.285354
# homeCurrentLadderPosition         NaN -0.108459   -0.506571      -0.304608
# awayCurrentLadderPosition         NaN -0.059909   -0.305957       0.327611
# homeBreak                         NaN  0.053802    0.032531       0.096374
# awayBreak                         NaN -0.039608   -0.095821       0.134160
#
#                                  awayTeamScore  rainfall   homeWin  \
# year                                       NaN       NaN       NaN
# round                                 0.019936 -0.036310 -0.007892
# attendance                            0.045352  0.033078  0.053480
# homeTeamScore                        -0.437422 -0.012509  0.685309
# awayTeamScore                         1.000000 -0.046046 -0.661747
# rainfall                             -0.046046  1.000000  0.060227
# homeWin                              -0.661747  0.060227  1.000000
# homeTeamLastWin                      -0.193387 -0.021006  0.109952
# awayTeamLastWin                       0.241228  0.127695 -0.085528
# awayTravel                            0.017686  0.009639 -0.021331
# homeTravel                           -0.094870 -0.057889  0.003147
# homeTeamChanges                       0.108883 -0.033581 -0.046164
# awayTeamChanges                      -0.248109 -0.134034  0.108408
# homeGameDifference                   -0.132241 -0.004115  0.076032
# awayGameDifference                   -0.057306 -0.021080  0.133651
# homeTeamImportanceDifference         -0.017012  0.036259 -0.076475
# awayTeamImportanceDifference          0.021152  0.071616 -0.048504
# homeTeamImportanceLastGame           -0.167531  0.032964  0.100875
# awayTeamImportanceLastGame            0.023556  0.034328 -0.046093
# homeTeamImportanceLastFiveGames      -0.217003  0.061944  0.169559
# awayTeamImportanceLastFiveGames      -0.022388  0.072287 -0.003200
# homeTeamImportanceSeasonAverage      -0.244063  0.065824  0.204291
# awayTeamImportanceSeasonAverage      -0.018727  0.087926 -0.016409
# homeLadderPosition                    0.242473 -0.019248 -0.330193
# awayLadderPosition                   -0.371127 -0.127566  0.281216
# homeTeamPointsFor                    -0.061718 -0.018628  0.097875
# homeTeamPointsAgainst                 0.112164 -0.041214 -0.088739
# homeTeamPercentage                   -0.321993  0.041305  0.332031
# awayTeamPointsFor                     0.166895 -0.025982 -0.108094
# awayTeamPointsAgainst                -0.093474 -0.050328  0.077125
# awayTeamPercentage                    0.329392  0.101016 -0.257261
# homeCurrentLadderPosition             0.255646  0.021039 -0.314820
# awayCurrentLadderPosition            -0.467312 -0.063421  0.287971
# homeBreak                            -0.044925 -0.114366  0.107374
# awayBreak                            -0.049842 -0.067304  0.030737
#
#                                  homeTeamLastWin  awayTeamLastWin  awayTravel  \
# year                                         NaN              NaN         NaN
# round                                   0.103898         0.123067    0.028575
# attendance                              0.271107         0.180365   -0.321810
# homeTeamScore                           0.053632        -0.067623   -0.072739
# awayTeamScore                          -0.193387         0.241228    0.017686
# rainfall                               -0.021006         0.127695    0.009639
# homeWin                                 0.109952        -0.085528   -0.021331
# homeTeamLastWin                         1.000000         0.069669    0.059309
# awayTeamLastWin                         0.069669         1.000000    0.112553
# awayTravel                              0.059309         0.112553    1.000000
# homeTravel                             -0.033052        -0.022533    0.163220
# homeTeamChanges                        -0.328829        -0.085143   -0.014575
# awayTeamChanges                        -0.031214        -0.270679   -0.045889
# homeGameDifference                      0.041367        -0.067921   -0.014798
# awayGameDifference                     -0.073256        -0.011691    0.102355
# homeTeamImportanceDifference            0.073856        -0.058382   -0.028131
# awayTeamImportanceDifference            0.031931         0.045897    0.161608
# homeTeamImportanceLastGame              0.262575         0.118162   -0.035642
# awayTeamImportanceLastGame              0.176379         0.358835    0.016063
# homeTeamImportanceLastFiveGames         0.266685         0.242047    0.011180
# awayTeamImportanceLastFiveGames         0.192987         0.352588    0.030956
# homeTeamImportanceSeasonAverage         0.288448         0.276522    0.036538
# awayTeamImportanceSeasonAverage         0.194444         0.368927    0.043580
# homeLadderPosition                     -0.284268        -0.104948    0.160807
# awayLadderPosition                     -0.071884        -0.335174   -0.070032
# homeTeamPointsFor                       0.206165         0.169606    0.007533
# homeTeamPointsAgainst                  -0.007692         0.079683    0.033479
# homeTeamPercentage                      0.504484         0.262525    0.043082
# awayTeamPointsFor                       0.078253         0.237899    0.046352
# awayTeamPointsAgainst                   0.088041         0.037901   -0.027077
# awayTeamPercentage                      0.104997         0.529336    0.203690
# homeCurrentLadderPosition              -0.514668        -0.183419   -0.023030
# awayCurrentLadderPosition              -0.062969        -0.467958   -0.254203
# homeBreak                               0.036139         0.004003    0.095043
# awayBreak                              -0.130712        -0.101463    0.006186
#
#                                  ...  homeTeamPointsFor  \
# year                             ...                NaN
# round                            ...           0.946386
# attendance                       ...           0.182790
# homeTeamScore                    ...           0.166833
# awayTeamScore                    ...          -0.061718
# rainfall                         ...          -0.018628
# homeWin                          ...           0.097875
# homeTeamLastWin                  ...           0.206165
# awayTeamLastWin                  ...           0.169606
# awayTravel                       ...           0.007533
# homeTravel                       ...          -0.010534
# homeTeamChanges                  ...           0.082931
# awayTeamChanges                  ...           0.131426
# homeGameDifference               ...          -0.000149
# awayGameDifference               ...          -0.007331
# homeTeamImportanceDifference     ...           0.109316
# awayTeamImportanceDifference     ...           0.101097
# homeTeamImportanceLastGame       ...           0.097696
# awayTeamImportanceLastGame       ...           0.201174
# homeTeamImportanceLastFiveGames  ...           0.288498
# awayTeamImportanceLastFiveGames  ...           0.290890
# homeTeamImportanceSeasonAverage  ...           0.342685
# awayTeamImportanceSeasonAverage  ...           0.300694
# homeLadderPosition               ...          -0.260351
# awayLadderPosition               ...          -0.034083
# homeTeamPointsFor                ...           1.000000
# homeTeamPointsAgainst            ...           0.841073
# homeTeamPercentage               ...           0.338398
# awayTeamPointsFor                ...           0.897374
# awayTeamPointsAgainst            ...           0.907250
# awayTeamPercentage               ...           0.208514
# homeCurrentLadderPosition        ...          -0.343653
# awayCurrentLadderPosition        ...          -0.071544
# homeBreak                        ...           0.072645
# awayBreak                        ...          -0.035569
#
#                                  homeTeamPointsAgainst  homeTeamPercentage  \
# year                                               NaN                 NaN
# round                                         0.962141            0.154306
# attendance                                   -0.085959            0.288828
# homeTeamScore                                -0.030124            0.302600
# awayTeamScore                                 0.112164           -0.321993
# rainfall                                     -0.041214            0.041305
# homeWin                                      -0.088739            0.332031
# homeTeamLastWin                              -0.007692            0.504484
# awayTeamLastWin                               0.079683            0.262525
# awayTravel                                    0.033479            0.043082
# homeTravel                                   -0.011072            0.008640
# homeTeamChanges                               0.312568           -0.124659
# awayTeamChanges                               0.159428            0.116113
# homeGameDifference                           -0.086448            0.040472
# awayGameDifference                            0.039308           -0.077906
# homeTeamImportanceDifference                  0.104577           -0.056675
# awayTeamImportanceDifference                  0.159740           -0.042017
# homeTeamImportanceLastGame                    0.116479            0.410048
# awayTeamImportanceLastGame                    0.243292            0.399710
# homeTeamImportanceLastFiveGames               0.228185            0.603865
# awayTeamImportanceLastFiveGames               0.303265            0.508996
# homeTeamImportanceSeasonAverage               0.247636            0.657329
# awayTeamImportanceSeasonAverage               0.305250            0.515637
# homeLadderPosition                            0.082963           -0.542514
# awayLadderPosition                            0.013963           -0.012383
# homeTeamPointsFor                             0.841073            0.338398
# homeTeamPointsAgainst                         1.000000           -0.011232
# homeTeamPercentage                           -0.011232            1.000000
# awayTeamPointsFor                             0.912145            0.144209
# awayTeamPointsAgainst                         0.930240            0.148520
# awayTeamPercentage                            0.217746            0.291991
# homeCurrentLadderPosition                     0.099568           -0.792943
# awayCurrentLadderPosition                    -0.042788            0.013245
# homeBreak                                     0.022252            0.132028
# awayBreak                                    -0.040504           -0.023193
#
#                                  awayTeamPointsFor  awayTeamPointsAgainst  \
# year                                           NaN                    NaN
# round                                     0.950499               0.962174
# attendance                                0.116121              -0.040166
# homeTeamScore                            -0.065772               0.154170
# awayTeamScore                             0.166895              -0.093474
# rainfall                                 -0.025982              -0.050328
# homeWin                                  -0.108094               0.077125
# homeTeamLastWin                           0.078253               0.088041
# awayTeamLastWin                           0.237899               0.037901
# awayTravel                                0.046352              -0.027077
# homeTravel                               -0.047581              -0.006049
# homeTeamChanges                           0.206445               0.245899
# awayTeamChanges                           0.043937               0.252957
# homeGameDifference                       -0.122912               0.015457
# awayGameDifference                       -0.036853               0.064696
# homeTeamImportanceDifference              0.048656               0.168965
# awayTeamImportanceDifference              0.127222               0.149563
# homeTeamImportanceLastGame                0.091004               0.146543
# awayTeamImportanceLastGame                0.266987               0.209901
# homeTeamImportanceLastFiveGames           0.256943               0.266039
# awayTeamImportanceLastFiveGames           0.352081               0.258639
# homeTeamImportanceSeasonAverage           0.299407               0.289886
# awayTeamImportanceSeasonAverage           0.363941               0.249115
# homeLadderPosition                       -0.087367              -0.055654
# awayLadderPosition                       -0.191062               0.133552
# homeTeamPointsFor                         0.897374               0.907250
# homeTeamPointsAgainst                     0.912145               0.930240
# homeTeamPercentage                        0.144209               0.148520
# awayTeamPointsFor                         1.000000               0.851489
# awayTeamPointsAgainst                     0.851489               1.000000
# awayTeamPercentage                        0.411015               0.057807
# homeCurrentLadderPosition                -0.127429              -0.071875
# awayCurrentLadderPosition                -0.288531               0.143742
# homeBreak                                 0.048563               0.059582
# awayBreak                                -0.055084              -0.024115
#
#                                  awayTeamPercentage  \
# year                                            NaN
# round                                      0.229212
# attendance                                 0.122881
# homeTeamScore                             -0.285354
# awayTeamScore                              0.329392
# rainfall                                   0.101016
# homeWin                                   -0.257261
# homeTeamLastWin                            0.104997
# awayTeamLastWin                            0.529336
# awayTravel                                 0.203690
# homeTravel                                -0.031640
# homeTeamChanges                            0.117664
# awayTeamChanges                           -0.094603
# homeGameDifference                        -0.155936
# awayGameDifference                        -0.068266
# homeTeamImportanceDifference              -0.090915
# awayTeamImportanceDifference               0.076168
# homeTeamImportanceLastGame                 0.351819
# awayTeamImportanceLastGame                 0.539129
# homeTeamImportanceLastFiveGames            0.514554
# awayTeamImportanceLastFiveGames            0.652204
# homeTeamImportanceSeasonAverage            0.545464
# awayTeamImportanceSeasonAverage            0.692729
# homeLadderPosition                        -0.069475
# awayLadderPosition                        -0.470763
# homeTeamPointsFor                          0.208514
# homeTeamPointsAgainst                      0.217746
# homeTeamPercentage                         0.291991
# awayTeamPointsFor                          0.411015
# awayTeamPointsAgainst                      0.057807
# awayTeamPercentage                         1.000000
# homeCurrentLadderPosition                 -0.113687
# awayCurrentLadderPosition                 -0.685314
# homeBreak                                 -0.006345
# awayBreak                                 -0.065355
#
#                                  homeCurrentLadderPosition  \
# year                                                   NaN
# round                                            -0.108459
# attendance                                       -0.506571
# homeTeamScore                                    -0.304608
# awayTeamScore                                     0.255646
# rainfall                                          0.021039
# homeWin                                          -0.314820
# homeTeamLastWin                                  -0.514668
# awayTeamLastWin                                  -0.183419
# awayTravel                                       -0.023030
# homeTravel                                        0.042713
# homeTeamChanges                                   0.298077
# awayTeamChanges                                   0.052453
# homeGameDifference                               -0.039917
# awayGameDifference                                0.125075
# homeTeamImportanceDifference                      0.035553
# awayTeamImportanceDifference                      0.061074
# homeTeamImportanceLastGame                       -0.078897
# awayTeamImportanceLastGame                       -0.060124
# homeTeamImportanceLastFiveGames                  -0.225624
# awayTeamImportanceLastFiveGames                  -0.136631
# homeTeamImportanceSeasonAverage                  -0.295778
# awayTeamImportanceSeasonAverage                  -0.147239
# homeLadderPosition                                0.659073
# awayLadderPosition                                0.122913
# homeTeamPointsFor                                -0.343653
# homeTeamPointsAgainst                             0.099568
# homeTeamPercentage                               -0.792943
# awayTeamPointsFor                                -0.127429
# awayTeamPointsAgainst                            -0.071875
# awayTeamPercentage                               -0.113687
# homeCurrentLadderPosition                         1.000000
# awayCurrentLadderPosition                         0.120929
# homeBreak                                        -0.083678
# awayBreak                                         0.034902
#
#                                  awayCurrentLadderPosition  homeBreak  \
# year                                                   NaN        NaN
# round                                            -0.059909   0.053802
# attendance                                       -0.305957   0.032531
# homeTeamScore                                     0.327611   0.096374
# awayTeamScore                                    -0.467312  -0.044925
# rainfall                                         -0.063421  -0.114366
# homeWin                                           0.287971   0.107374
# homeTeamLastWin                                  -0.062969   0.036139
# awayTeamLastWin                                  -0.467958   0.004003
# awayTravel                                       -0.254203   0.095043
# homeTravel                                        0.092624  -0.018920
# homeTeamChanges                                   0.119178   0.002298
# awayTeamChanges                                   0.326121  -0.011783
# homeGameDifference                                0.174946   0.078631
# awayGameDifference                                0.084689  -0.071153
# homeTeamImportanceDifference                      0.188926  -0.007008
# awayTeamImportanceDifference                     -0.055732  -0.144622
# homeTeamImportanceLastGame                        0.144981  -0.060250
# awayTeamImportanceLastGame                       -0.054498   0.083550
# homeTeamImportanceLastFiveGames                   0.072077   0.041518
# awayTeamImportanceLastFiveGames                  -0.088316   0.065562
# homeTeamImportanceSeasonAverage                   0.035003   0.061824
# awayTeamImportanceSeasonAverage                  -0.135559   0.057151
# homeLadderPosition                                0.061961  -0.117402
# awayLadderPosition                                0.670682   0.065404
# homeTeamPointsFor                                -0.071544   0.072645
# homeTeamPointsAgainst                            -0.042788   0.022252
# homeTeamPercentage                                0.013245   0.132028
# awayTeamPointsFor                                -0.288531   0.048563
# awayTeamPointsAgainst                             0.143742   0.059582
# awayTeamPercentage                               -0.685314  -0.006345
# homeCurrentLadderPosition                         0.120929  -0.083678
# awayCurrentLadderPosition                         1.000000   0.024212
# homeBreak                                         0.024212   1.000000
# awayBreak                                         0.107160   0.283017
#
#                                  awayBreak
# year                                   NaN
# round                            -0.039608
# attendance                       -0.095821
# homeTeamScore                     0.134160
# awayTeamScore                    -0.049842
# rainfall                         -0.067304
# homeWin                           0.030737
# homeTeamLastWin                  -0.130712
# awayTeamLastWin                  -0.101463
# awayTravel                        0.006186
# homeTravel                       -0.015549
# homeTeamChanges                   0.014955
# awayTeamChanges                   0.144880
# homeGameDifference                0.101619
# awayGameDifference                0.081524
# homeTeamImportanceDifference      0.059393
# awayTeamImportanceDifference     -0.060819
# homeTeamImportanceLastGame        0.093692
# awayTeamImportanceLastGame        0.053958
# homeTeamImportanceLastFiveGames   0.068692
# awayTeamImportanceLastFiveGames   0.014428
# homeTeamImportanceSeasonAverage   0.040158
# awayTeamImportanceSeasonAverage  -0.000334
# homeLadderPosition               -0.033361
# awayLadderPosition                0.131823
# homeTeamPointsFor                -0.035569
# homeTeamPointsAgainst            -0.040504
# homeTeamPercentage               -0.023193
# awayTeamPointsFor                -0.055084
# awayTeamPointsAgainst            -0.024115
# awayTeamPercentage               -0.065355
# homeCurrentLadderPosition         0.034902
# awayCurrentLadderPosition         0.107160
# homeBreak                         0.283017
# awayBreak                         1.000000
#
# [35 rows x 35 columns]

# %%
ax = games_raw_2012.plot.scatter('homeWin', 'homeCurrentLadderPosition')
