# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,roc_auc_score,confusion_matrix,accuracy_score,f1_score,roc_curve, ConfusionMatrixDisplay
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler

from keras.models import Sequential
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.layers import Dense, Embedding, LSTM
from keras.utils import to_categorical

from IPython.display import display
import random
import matplotlib.pyplot as plt
# random.seed(10)

# %%
# Import Data
games_folder_path = "C:/Users/Craig/Documents/Thesis/Thomas_Gallagher_Thesis/Data/AFL_Stats_sorted/Year/Games/"
games_2012 = pd.read_csv(games_folder_path + '2012.csv', index_col=False, parse_dates=['date'])
games_2013 = pd.read_csv(games_folder_path + '2013.csv', index_col=False, parse_dates=['date'])
games_2014 = pd.read_csv(games_folder_path + '2014.csv', index_col=False, parse_dates=['date'])
games_2015 = pd.read_csv(games_folder_path + '2015.csv', index_col=False, parse_dates=['date'])
games_2016 = pd.read_csv(games_folder_path + '2016.csv', index_col=False, parse_dates=['date'])
games_2017 = pd.read_csv(games_folder_path + '2017.csv', index_col=False, parse_dates=['date'])
games_2018 = pd.read_csv(games_folder_path + '2018.csv', index_col=False, parse_dates=['date'])
games_2019 = pd.read_csv(games_folder_path + '2019.csv', index_col=False, parse_dates=['date'])
games_2020 = pd.read_csv(games_folder_path + '2020.csv', index_col=False, parse_dates=['date'])
games_2021 = pd.read_csv(games_folder_path + '2021.csv', index_col=False, parse_dates=['date'])


all_games = pd.read_csv(games_folder_path + 'games_sorted.csv', index_col=False, parse_dates=['date'])
# Out:
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2012 = pd.read_csv(games_folder_path + '2012.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2013 = pd.read_csv(games_folder_path + '2013.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2014 = pd.read_csv(games_folder_path + '2014.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2015 = pd.read_csv(games_folder_path + '2015.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2016 = pd.read_csv(games_folder_path + '2016.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:8: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2017 = pd.read_csv(games_folder_path + '2017.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:9: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2018 = pd.read_csv(games_folder_path + '2018.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:10: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2019 = pd.read_csv(games_folder_path + '2019.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:11: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2020 = pd.read_csv(games_folder_path + '2020.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_13676\3458396436.py:12: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2021 = pd.read_csv(games_folder_path + '2021.csv', index_col=False, parse_dates=['date'])

# %%
# One Hot Encoding Teams
encoding = LabelEncoder()
encoding.fit(all_games["homeTeam"].values)


def OHE_Teams(games):
    home_teams = encoding.transform(games["homeTeam"].values)
    away_teams = encoding.transform(games["awayTeam"].values)

    all_teams = np.vstack([home_teams, away_teams]).T
 
    oneHot = OneHotEncoder()
    X_teams = oneHot.fit_transform(all_teams).todense()
    X_teams = pd.DataFrame(X_teams)
    games = pd.concat([games, pd.DataFrame(X_teams)],axis=1)
    return games

games_2012 = OHE_Teams(games_2012)
games_2013 = OHE_Teams(games_2013)
games_2014 = OHE_Teams(games_2014)
games_2015 = OHE_Teams(games_2015)
games_2016 = OHE_Teams(games_2016)
games_2017 = OHE_Teams(games_2017)
games_2018 = OHE_Teams(games_2018)
games_2019 = OHE_Teams(games_2019)
games_2020 = OHE_Teams(games_2020)
games_2021 = OHE_Teams(games_2021)

all_games = OHE_Teams(all_games)

# %%
# One Hot Encoding Venues
encoding = LabelEncoder()
encoding.fit(all_games["venue"].values)
all_venues = all_games["venue"].values

all_venues = all_venues.reshape(-1,1)

def OHE_Venues(games):
    venues = games['venue'].values
    # all_venues = all_venues.reshape(-1,1)
    venues = venues.reshape(-1,1)
    oneHot = OneHotEncoder()

    oneHot.fit(all_venues)
    X_venues = oneHot.transform(venues).toarray()
    X_venues = pd.DataFrame(X_venues, columns=oneHot.categories_[0])
    games = pd.concat([games, X_venues], axis=1)
    return games

games_2012 = OHE_Venues(games_2012)
games_2013 = OHE_Venues(games_2013)
games_2014 = OHE_Venues(games_2014)
games_2015 = OHE_Venues(games_2015)
games_2016 = OHE_Venues(games_2016)
games_2017 = OHE_Venues(games_2017)
games_2018 = OHE_Venues(games_2018)
games_2019 = OHE_Venues(games_2019)
games_2020 = OHE_Venues(games_2020)
games_2021 = OHE_Venues(games_2021)

all_games = OHE_Venues(all_games)

# %%
def split_time(row):
    time = row['startTime']
    time = time.split(':')
    time = ''.join(time[:2])
    row['startTime'] = time
    return row

games_2012 = games_2012.apply(split_time, axis=1)
games_2013 = games_2013.apply(split_time, axis=1)
games_2014 = games_2014.apply(split_time, axis=1)
games_2015 = games_2015.apply(split_time, axis=1)
games_2016 = games_2016.apply(split_time, axis=1)
games_2017 = games_2017.apply(split_time, axis=1)
games_2018 = games_2018.apply(split_time, axis=1)
games_2019 = games_2019.apply(split_time, axis=1)
games_2020 = games_2020.apply(split_time, axis=1)
games_2021 = games_2021.apply(split_time, axis=1)

# %%
y_true_2012 = games_2012['homeWin']
y_true_2013 = games_2013['homeWin']
y_true_2014 = games_2014['homeWin']
y_true_2015 = games_2015['homeWin']
y_true_2016 = games_2016['homeWin']
y_true_2017 = games_2017['homeWin']
y_true_2018 = games_2018['homeWin']
y_true_2019 = games_2019['homeWin']
y_true_2020 = games_2020['homeWin']
y_true_2021 = games_2021['homeWin']
y_true = all_games['homeWin']

drop_values = ['gameId', 'venue', 'homeWin', 'homeTeam', 'awayTeam', 'year','date', 'homeTeamScore', 'awayTeamScore', 'round']

def drop_columns(game_list):
    game_list = game_list.drop(drop_values,axis=1)
    game_list.columns = game_list.columns.astype(str)
    return game_list

games_2012 = drop_columns(games_2012)
games_2013 = drop_columns(games_2013)
games_2014 = drop_columns(games_2014)
games_2015 = drop_columns(games_2015)
games_2016 = drop_columns(games_2016)
games_2017 = drop_columns(games_2017)
games_2018 = drop_columns(games_2018)
games_2019 = drop_columns(games_2019)
games_2020 = drop_columns(games_2020)
games_2021 = drop_columns(games_2021)

all_games = drop_columns(all_games)

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
games_2012 = scaler.fit_transform(games_2012)
games_2013 = scaler.fit_transform(games_2013)
games_2014 = scaler.fit_transform(games_2014)
games_2015 = scaler.fit_transform(games_2015)
games_2016 = scaler.fit_transform(games_2016)
games_2017 = scaler.fit_transform(games_2017)
games_2018 = scaler.fit_transform(games_2018)
games_2019 = scaler.fit_transform(games_2019)
games_2020 = scaler.fit_transform(games_2020)
games_2021 = scaler.fit_transform(games_2021)

# %%
y_train_2012 = y_true_2012[9:171]
y_valid_2012 = y_true_2012[171:]

y_train_2013 = y_true_2013[9:171]
y_valid_2013 = y_true_2013[171:]

y_train_2014 = y_true_2014[9:171]
y_valid_2014 = y_true_2014[171:]

y_train_2015 = y_true_2015[9:170]
y_valid_2015 = y_true_2015[170:]

y_train_2016 = y_true_2016[9:171]
y_valid_2016 = y_true_2016[171:]

y_train_2017 = y_true_2017[9:171]
y_valid_2017 = y_true_2017[171:]

y_train_2018 = y_true_2018[9:171]
y_valid_2018 = y_true_2018[171:]

y_train_2019 = y_true_2019[9:171]
y_valid_2019 = y_true_2019[171:]

y_train_2020 = y_true_2020[9:127]
y_valid_2020 = y_true_2020[127:]

y_train_2021 = y_true_2021[9:171]
y_valid_2021 = y_true_2021[171:]

y_train = y_true[:1447]
y_valid = y_true[1447:1655]

# %%
# OHE Y values
oneHot = OneHotEncoder()
def OHE_y_values(y_val):
    y = np.vstack([y_val]).T
    
    # for i in range(len(y)):
    #     if y[i] == 1:
    #         y[i] = 0

    y_OHE = oneHot.fit_transform(y).toarray()

    return y_OHE


y_train_2012_OHE = OHE_y_values(y_train_2012)
y_valid_2012_OHE = OHE_y_values(y_valid_2012)

y_train_2013_OHE = OHE_y_values(y_train_2013)
y_valid_2013_OHE = OHE_y_values(y_valid_2013)

y_train_2014_OHE = OHE_y_values(y_train_2014)
y_valid_2014_OHE = OHE_y_values(y_valid_2014)

y_train_2015_OHE = OHE_y_values(y_train_2015)
y_valid_2015_OHE = OHE_y_values(y_valid_2015)

y_train_2016_OHE = OHE_y_values(y_train_2016)
y_valid_2016_OHE = OHE_y_values(y_valid_2016)

y_train_2017_OHE = OHE_y_values(y_train_2017)
y_valid_2017_OHE = OHE_y_values(y_valid_2017)

y_train_2018_OHE = OHE_y_values(y_train_2018)
y_valid_2018_OHE = OHE_y_values(y_valid_2018)

y_train_2019_OHE = OHE_y_values(y_train_2019)
y_valid_2019_OHE = OHE_y_values(y_valid_2019)

y_train_2020_OHE = OHE_y_values(y_train_2020)
y_valid_2020_OHE = OHE_y_values(y_valid_2020)

y_train_2021_OHE = OHE_y_values(y_train_2021)
y_valid_2021_OHE = OHE_y_values(y_valid_2021)

y_train_OHE = OHE_y_values(y_train)
y_valid_OHE = OHE_y_values(y_valid)

# %%
def set_window(games):
    y = 0
    p = 0
    d_full = np.zeros(shape=(1980,92))
    for x in range(0,d_full.shape[0],10): # Goes through index for each round
        y = 9 # link to previous round
        if x % 90 == 0:
            p += 1 # move to next round when 90 index is reached
        for i in range(9): # fills out the first nine posistions in the window with previous games
                d_full[x+i] = games[p+i] # at pos x add corresponding previous game
        d_full[x+y] = games[x//10 + y] # add game in question to final position
        
    d_Train = d_full[:1620]
    d_valid = d_full[1620:]
    d_Train = np.reshape(d_Train, (162, 10,92))
    d_valid = np.reshape(d_valid, (36, 10, 92))
    return d_Train, d_valid

x_train_2012, x_valid_2012 = set_window(games_2012)
x_train_2013, x_valid_2013 = set_window(games_2013)
x_train_2014, x_valid_2014 = set_window(games_2014)
# x_train_2015, x_valid_2015 = set_window(games_2015)
x_train_2016, x_valid_2016 = set_window(games_2016)
x_train_2017, x_valid_2017 = set_window(games_2017)
x_train_2018, x_valid_2018 = set_window(games_2018)
x_train_2019, x_valid_2019 = set_window(games_2019)
# x_train_2020, x_valid_2020 = set_window(games_2020)

# %%
def set_window_2015(games):
    y = 0
    p = 0
    d_full = np.zeros(shape=(1970,92))
    for x in range(0,d_full.shape[0],10): # Goes through index for each round
        y = 9 # link to previous round
        if x % 90 == 0:
            p += 1 # move to next round when 90 index is reached
        for i in range(9): # fills out the first nine posistions in the window with previous games
                d_full[x+i] = games[p+i] # at pos x add corresponding previous game
            
        d_full[x+y] = games[x//10 + y] # add game in question to final position
        
    d_Train = d_full[:1610]
    d_valid = d_full[1610:]
    d_Train = np.reshape(d_Train, (161, 10,92))
    d_valid = np.reshape(d_valid, (36, 10, 92))
    return d_Train, d_valid

x_train_2015, x_valid_2015 = set_window_2015(games_2015)

# %%
def train_model_4( xTrain, yTrain, xValid , yValid):
    random.seed(26)
    model = Sequential()
    model.add(LSTM( 128 ,input_shape = (10,92), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3))
    model.add(Dense(2, activation="tanh"))
    model.build()   
    model.summary()
    model.compile( optimizer = "rmsprop" , loss = 'mean_squared_error' , metrics = ['accuracy', 'mse'])

    reduce_lr = ReduceLROnPlateau( monitor = 'accuracy', factor = 0.01, patience=10, cooldown=0)
    
    callbacks = [ reduce_lr ]
    model.fit( xTrain, yTrain , epochs = 50, shuffle=False, callbacks=callbacks, verbose = 2)

    # train_history = model.fit( x_train_2012 , y_train_2012 , epochs = 10, validation_split = 0.1 , verbose = 1 )
    score = model.evaluate( xValid , yValid )
    pred = model.predict(xValid)
    model.save("LSTM_4")
    # print( f"Train Accuracy: {train_history.history}" )
    
    print( "Accuracy: {:0.4}".format( score[1] ))
    print( "Loss:", score[0] )
    return score, pred

# %%
results_2012, pred_2012 = train_model_4(x_train_2012, y_train_2012_OHE, x_valid_2012, y_valid_2012_OHE) 
results_2013, pred_2013 = train_model_4(x_train_2013, y_train_2013_OHE, x_valid_2013, y_valid_2013_OHE) 
results_2014, pred_2014 = train_model_4(x_train_2014, y_train_2014_OHE, x_valid_2014, y_valid_2014_OHE) 
results_2015, pred_2015 = train_model_4(x_train_2015, y_train_2015_OHE, x_valid_2015, y_valid_2015_OHE) 
results_2016, pred_2016 = train_model_4(x_train_2016, y_train_2016_OHE, x_valid_2016, y_valid_2016_OHE) 
results_2017, pred_2017 = train_model_4(x_train_2017, y_train_2017_OHE, x_valid_2017, y_valid_2017_OHE) 
results_2018, pred_2018 = train_model_4(x_train_2018, y_train_2018_OHE, x_valid_2018, y_valid_2018_OHE) 
results_2019, pred_2019 = train_model_4(x_train_2019, y_train_2019_OHE, x_valid_2019, y_valid_2019_OHE)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 128)               113152
#
#  dense_24 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 113,410
# Trainable params: 113,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 6/6 - 4s - loss: 0.3441 - accuracy: 0.4630 - mse: 0.3441 - lr: 0.0010 - 4s/epoch - 618ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.2405 - accuracy: 0.5864 - mse: 0.2405 - lr: 0.0010 - 117ms/epoch - 19ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.2321 - accuracy: 0.6420 - mse: 0.2321 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.2318 - accuracy: 0.5617 - mse: 0.2318 - lr: 0.0010 - 93ms/epoch - 15ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.2304 - accuracy: 0.6235 - mse: 0.2304 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.2157 - accuracy: 0.6790 - mse: 0.2157 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.2157 - accuracy: 0.6605 - mse: 0.2157 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.2067 - accuracy: 0.6975 - mse: 0.2067 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.2034 - accuracy: 0.7160 - mse: 0.2034 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.2074 - accuracy: 0.6790 - mse: 0.2074 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.1890 - accuracy: 0.7099 - mse: 0.1890 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.1874 - accuracy: 0.7346 - mse: 0.1874 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.1879 - accuracy: 0.7407 - mse: 0.1879 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.1769 - accuracy: 0.7099 - mse: 0.1769 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.1792 - accuracy: 0.7531 - mse: 0.1792 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.1855 - accuracy: 0.7284 - mse: 0.1855 - lr: 0.0010 - 81ms/epoch - 13ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.1707 - accuracy: 0.7531 - mse: 0.1707 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.1691 - accuracy: 0.7407 - mse: 0.1691 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.1782 - accuracy: 0.7284 - mse: 0.1782 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.1697 - accuracy: 0.7531 - mse: 0.1697 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 0.1627 - accuracy: 0.7778 - mse: 0.1627 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 0.1718 - accuracy: 0.7469 - mse: 0.1718 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 0.1585 - accuracy: 0.7963 - mse: 0.1585 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 0.1570 - accuracy: 0.7901 - mse: 0.1570 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 0.1599 - accuracy: 0.7901 - mse: 0.1599 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 0.1516 - accuracy: 0.7963 - mse: 0.1516 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 0.1593 - accuracy: 0.7716 - mse: 0.1593 - lr: 0.0010 - 167ms/epoch - 28ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 0.1526 - accuracy: 0.8025 - mse: 0.1526 - lr: 0.0010 - 94ms/epoch - 16ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 0.1481 - accuracy: 0.7840 - mse: 0.1481 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 0.1480 - accuracy: 0.8025 - mse: 0.1480 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 0.1532 - accuracy: 0.8086 - mse: 0.1532 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 0.1384 - accuracy: 0.8086 - mse: 0.1384 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 0.1481 - accuracy: 0.8148 - mse: 0.1481 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 0.1452 - accuracy: 0.8210 - mse: 0.1452 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 0.1379 - accuracy: 0.7963 - mse: 0.1379 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 0.1408 - accuracy: 0.8148 - mse: 0.1408 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 0.1422 - accuracy: 0.8148 - mse: 0.1422 - lr: 0.0010 - 87ms/epoch - 15ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 0.1408 - accuracy: 0.7963 - mse: 0.1408 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 0.1491 - accuracy: 0.8025 - mse: 0.1491 - lr: 0.0010 - 93ms/epoch - 16ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 0.1258 - accuracy: 0.8457 - mse: 0.1258 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 0.1389 - accuracy: 0.8210 - mse: 0.1389 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 0.1233 - accuracy: 0.8580 - mse: 0.1233 - lr: 0.0010 - 93ms/epoch - 16ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 0.1422 - accuracy: 0.8210 - mse: 0.1422 - lr: 0.0010 - 103ms/epoch - 17ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 0.1329 - accuracy: 0.8086 - mse: 0.1329 - lr: 0.0010 - 138ms/epoch - 23ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 0.1398 - accuracy: 0.8148 - mse: 0.1398 - lr: 0.0010 - 98ms/epoch - 16ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 0.1317 - accuracy: 0.8395 - mse: 0.1317 - lr: 0.0010 - 93ms/epoch - 15ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 0.1356 - accuracy: 0.8765 - mse: 0.1356 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 0.1275 - accuracy: 0.8395 - mse: 0.1275 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 0.1293 - accuracy: 0.8333 - mse: 0.1293 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 0.1442 - accuracy: 0.7840 - mse: 0.1442 - lr: 0.0010 - 87ms/epoch - 14ms/step
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2341 - accuracy: 0.6667 - mse: 0.2341
# 2/2 [==============================] - 0s 5ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_4\assets
# INFO:tensorflow:Assets written to: LSTM_4\assets
# Accuracy: 0.6667
# Loss: 0.2340921014547348
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_25 (LSTM)              (None, 128)               113152
#
#  dense_25 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 113,410
# Trainable params: 113,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 6/6 - 3s - loss: 0.3375 - accuracy: 0.5062 - mse: 0.3375 - lr: 0.0010 - 3s/epoch - 532ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.2665 - accuracy: 0.5617 - mse: 0.2665 - lr: 0.0010 - 101ms/epoch - 17ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.2524 - accuracy: 0.5556 - mse: 0.2524 - lr: 0.0010 - 102ms/epoch - 17ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.2364 - accuracy: 0.5864 - mse: 0.2364 - lr: 0.0010 - 94ms/epoch - 16ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.2327 - accuracy: 0.5926 - mse: 0.2327 - lr: 0.0010 - 96ms/epoch - 16ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.2265 - accuracy: 0.5802 - mse: 0.2265 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.2286 - accuracy: 0.6049 - mse: 0.2286 - lr: 0.0010 - 96ms/epoch - 16ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.2269 - accuracy: 0.6049 - mse: 0.2269 - lr: 0.0010 - 96ms/epoch - 16ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.2163 - accuracy: 0.6543 - mse: 0.2163 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.2186 - accuracy: 0.6481 - mse: 0.2186 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.2119 - accuracy: 0.6914 - mse: 0.2119 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.2015 - accuracy: 0.6852 - mse: 0.2015 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.2027 - accuracy: 0.6790 - mse: 0.2027 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.2019 - accuracy: 0.6852 - mse: 0.2019 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.1930 - accuracy: 0.7099 - mse: 0.1930 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.1974 - accuracy: 0.7284 - mse: 0.1974 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.1883 - accuracy: 0.7160 - mse: 0.1883 - lr: 0.0010 - 122ms/epoch - 20ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.1862 - accuracy: 0.7469 - mse: 0.1862 - lr: 0.0010 - 137ms/epoch - 23ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.1799 - accuracy: 0.7593 - mse: 0.1799 - lr: 0.0010 - 98ms/epoch - 16ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.1686 - accuracy: 0.7593 - mse: 0.1686 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 0.1791 - accuracy: 0.7346 - mse: 0.1791 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 0.1628 - accuracy: 0.7963 - mse: 0.1628 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 0.1677 - accuracy: 0.7593 - mse: 0.1677 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 0.1634 - accuracy: 0.7778 - mse: 0.1634 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 0.1654 - accuracy: 0.7716 - mse: 0.1654 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 0.1621 - accuracy: 0.7716 - mse: 0.1621 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 0.1629 - accuracy: 0.7901 - mse: 0.1629 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 0.1573 - accuracy: 0.7963 - mse: 0.1573 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 0.1579 - accuracy: 0.7901 - mse: 0.1579 - lr: 0.0010 - 94ms/epoch - 16ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 0.1429 - accuracy: 0.8395 - mse: 0.1429 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 0.1561 - accuracy: 0.7716 - mse: 0.1561 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 0.1475 - accuracy: 0.8086 - mse: 0.1475 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 0.1423 - accuracy: 0.8210 - mse: 0.1423 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 0.1389 - accuracy: 0.8457 - mse: 0.1389 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 0.1418 - accuracy: 0.8086 - mse: 0.1418 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 0.1490 - accuracy: 0.8333 - mse: 0.1490 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 0.1354 - accuracy: 0.8210 - mse: 0.1354 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 0.1327 - accuracy: 0.8642 - mse: 0.1327 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 0.1460 - accuracy: 0.8148 - mse: 0.1460 - lr: 0.0010 - 140ms/epoch - 23ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 0.1343 - accuracy: 0.8457 - mse: 0.1343 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 0.1349 - accuracy: 0.8395 - mse: 0.1349 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 0.1383 - accuracy: 0.8457 - mse: 0.1383 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 0.1235 - accuracy: 0.8580 - mse: 0.1235 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 0.1458 - accuracy: 0.7778 - mse: 0.1458 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 0.1401 - accuracy: 0.8333 - mse: 0.1401 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 0.1341 - accuracy: 0.8210 - mse: 0.1341 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 0.1295 - accuracy: 0.8395 - mse: 0.1295 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 0.1333 - accuracy: 0.8333 - mse: 0.1333 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 0.1374 - accuracy: 0.8210 - mse: 0.1374 - lr: 1.0000e-05 - 84ms/epoch - 14ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 0.1422 - accuracy: 0.7840 - mse: 0.1422 - lr: 1.0000e-05 - 84ms/epoch - 14ms/step
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2215 - accuracy: 0.6944 - mse: 0.2215
# 2/2 [==============================] - 0s 5ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_4\assets
# INFO:tensorflow:Assets written to: LSTM_4\assets
# Accuracy: 0.6944
# Loss: 0.22152850031852722
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_26 (LSTM)              (None, 128)               113152
#
#  dense_26 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 113,410
# Trainable params: 113,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 6/6 - 4s - loss: 0.3232 - accuracy: 0.5185 - mse: 0.3232 - lr: 0.0010 - 4s/epoch - 661ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.2383 - accuracy: 0.6235 - mse: 0.2383 - lr: 0.0010 - 110ms/epoch - 18ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.2361 - accuracy: 0.6049 - mse: 0.2361 - lr: 0.0010 - 95ms/epoch - 16ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.2329 - accuracy: 0.6049 - mse: 0.2329 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.2240 - accuracy: 0.6543 - mse: 0.2240 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.2213 - accuracy: 0.6481 - mse: 0.2213 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.2246 - accuracy: 0.6914 - mse: 0.2246 - lr: 0.0010 - 93ms/epoch - 15ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.2150 - accuracy: 0.6975 - mse: 0.2150 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.2250 - accuracy: 0.6420 - mse: 0.2250 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.2094 - accuracy: 0.6914 - mse: 0.2094 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.2123 - accuracy: 0.6605 - mse: 0.2123 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.1979 - accuracy: 0.7531 - mse: 0.1979 - lr: 0.0010 - 81ms/epoch - 13ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.2264 - accuracy: 0.6296 - mse: 0.2264 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.1916 - accuracy: 0.7284 - mse: 0.1916 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.1885 - accuracy: 0.7284 - mse: 0.1885 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.1978 - accuracy: 0.7346 - mse: 0.1978 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.1851 - accuracy: 0.7407 - mse: 0.1851 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.1874 - accuracy: 0.7346 - mse: 0.1874 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.1845 - accuracy: 0.7531 - mse: 0.1845 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.1803 - accuracy: 0.7222 - mse: 0.1803 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 0.1826 - accuracy: 0.7407 - mse: 0.1826 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 0.1902 - accuracy: 0.7222 - mse: 0.1902 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 0.1695 - accuracy: 0.7840 - mse: 0.1695 - lr: 1.0000e-05 - 84ms/epoch - 14ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 0.1533 - accuracy: 0.8210 - mse: 0.1533 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 0.1722 - accuracy: 0.7716 - mse: 0.1722 - lr: 1.0000e-05 - 86ms/epoch - 14ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 0.1676 - accuracy: 0.7469 - mse: 0.1676 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 0.1733 - accuracy: 0.7654 - mse: 0.1733 - lr: 1.0000e-05 - 87ms/epoch - 14ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 0.1806 - accuracy: 0.7407 - mse: 0.1806 - lr: 1.0000e-05 - 84ms/epoch - 14ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 0.1715 - accuracy: 0.7654 - mse: 0.1715 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 0.1694 - accuracy: 0.7654 - mse: 0.1694 - lr: 1.0000e-05 - 166ms/epoch - 28ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 0.1683 - accuracy: 0.7407 - mse: 0.1683 - lr: 1.0000e-05 - 101ms/epoch - 17ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 0.1682 - accuracy: 0.7778 - mse: 0.1682 - lr: 1.0000e-05 - 87ms/epoch - 14ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 0.1669 - accuracy: 0.8148 - mse: 0.1669 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 0.1656 - accuracy: 0.7716 - mse: 0.1656 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 0.1688 - accuracy: 0.7901 - mse: 0.1688 - lr: 1.0000e-07 - 83ms/epoch - 14ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 0.1626 - accuracy: 0.8025 - mse: 0.1626 - lr: 1.0000e-07 - 85ms/epoch - 14ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 0.1661 - accuracy: 0.7778 - mse: 0.1661 - lr: 1.0000e-07 - 127ms/epoch - 21ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 0.1855 - accuracy: 0.7037 - mse: 0.1855 - lr: 1.0000e-07 - 91ms/epoch - 15ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 0.1689 - accuracy: 0.7901 - mse: 0.1689 - lr: 1.0000e-07 - 84ms/epoch - 14ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 0.1646 - accuracy: 0.7901 - mse: 0.1646 - lr: 1.0000e-07 - 85ms/epoch - 14ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 0.1706 - accuracy: 0.7840 - mse: 0.1706 - lr: 1.0000e-07 - 85ms/epoch - 14ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 0.1733 - accuracy: 0.7469 - mse: 0.1733 - lr: 1.0000e-07 - 86ms/epoch - 14ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 0.1644 - accuracy: 0.7840 - mse: 0.1644 - lr: 1.0000e-07 - 84ms/epoch - 14ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 0.1595 - accuracy: 0.8025 - mse: 0.1595 - lr: 1.0000e-07 - 86ms/epoch - 14ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 0.1661 - accuracy: 0.7840 - mse: 0.1661 - lr: 1.0000e-09 - 84ms/epoch - 14ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 0.1604 - accuracy: 0.8025 - mse: 0.1604 - lr: 1.0000e-09 - 85ms/epoch - 14ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 0.1781 - accuracy: 0.8025 - mse: 0.1781 - lr: 1.0000e-09 - 88ms/epoch - 15ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 0.1665 - accuracy: 0.7840 - mse: 0.1665 - lr: 1.0000e-09 - 82ms/epoch - 14ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 0.1669 - accuracy: 0.7654 - mse: 0.1669 - lr: 1.0000e-09 - 88ms/epoch - 15ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 0.1797 - accuracy: 0.7407 - mse: 0.1797 - lr: 1.0000e-09 - 82ms/epoch - 14ms/step
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2202 - accuracy: 0.6667 - mse: 0.2202
# 2/2 [==============================] - 0s 5ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_4\assets
# INFO:tensorflow:Assets written to: LSTM_4\assets
# Accuracy: 0.6667
# Loss: 0.22018638253211975
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_27 (LSTM)              (None, 128)               113152
#
#  dense_27 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 113,410
# Trainable params: 113,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 6/6 - 3s - loss: 0.3455 - accuracy: 0.4783 - mse: 0.3455 - lr: 0.0010 - 3s/epoch - 525ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.2672 - accuracy: 0.5404 - mse: 0.2672 - lr: 0.0010 - 96ms/epoch - 16ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.2503 - accuracy: 0.5590 - mse: 0.2503 - lr: 0.0010 - 95ms/epoch - 16ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.2416 - accuracy: 0.5839 - mse: 0.2416 - lr: 0.0010 - 94ms/epoch - 16ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.2435 - accuracy: 0.5714 - mse: 0.2435 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.2379 - accuracy: 0.5590 - mse: 0.2379 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.2311 - accuracy: 0.6398 - mse: 0.2311 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.2307 - accuracy: 0.6087 - mse: 0.2307 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.2240 - accuracy: 0.6398 - mse: 0.2240 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.2182 - accuracy: 0.6832 - mse: 0.2182 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.2251 - accuracy: 0.6335 - mse: 0.2251 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.2249 - accuracy: 0.6149 - mse: 0.2249 - lr: 0.0010 - 120ms/epoch - 20ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.2150 - accuracy: 0.6522 - mse: 0.2150 - lr: 0.0010 - 119ms/epoch - 20ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.2171 - accuracy: 0.6460 - mse: 0.2171 - lr: 0.0010 - 101ms/epoch - 17ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.2106 - accuracy: 0.6584 - mse: 0.2106 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.2020 - accuracy: 0.7019 - mse: 0.2020 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.1936 - accuracy: 0.7391 - mse: 0.1936 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.1973 - accuracy: 0.7019 - mse: 0.1973 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.1983 - accuracy: 0.6584 - mse: 0.1983 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.1892 - accuracy: 0.7329 - mse: 0.1892 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 0.1799 - accuracy: 0.7391 - mse: 0.1799 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 0.1809 - accuracy: 0.7019 - mse: 0.1809 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 0.1813 - accuracy: 0.7640 - mse: 0.1813 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 0.1737 - accuracy: 0.7826 - mse: 0.1737 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 0.1789 - accuracy: 0.7453 - mse: 0.1789 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 0.1640 - accuracy: 0.7950 - mse: 0.1640 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 0.1775 - accuracy: 0.7516 - mse: 0.1775 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 0.1624 - accuracy: 0.7578 - mse: 0.1624 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 0.1563 - accuracy: 0.7826 - mse: 0.1563 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 0.1692 - accuracy: 0.7888 - mse: 0.1692 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 0.1460 - accuracy: 0.8199 - mse: 0.1460 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 0.1879 - accuracy: 0.7205 - mse: 0.1879 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 0.1588 - accuracy: 0.7950 - mse: 0.1588 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 0.1742 - accuracy: 0.7267 - mse: 0.1742 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 0.1616 - accuracy: 0.7888 - mse: 0.1616 - lr: 0.0010 - 135ms/epoch - 22ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 0.1597 - accuracy: 0.7764 - mse: 0.1597 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 0.1760 - accuracy: 0.7578 - mse: 0.1760 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 0.1594 - accuracy: 0.7764 - mse: 0.1594 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 0.1669 - accuracy: 0.7516 - mse: 0.1669 - lr: 0.0010 - 81ms/epoch - 13ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 0.1486 - accuracy: 0.8012 - mse: 0.1486 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 0.1573 - accuracy: 0.7702 - mse: 0.1573 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 0.1905 - accuracy: 0.6957 - mse: 0.1905 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 0.1743 - accuracy: 0.7702 - mse: 0.1743 - lr: 1.0000e-05 - 81ms/epoch - 13ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 0.1725 - accuracy: 0.7640 - mse: 0.1725 - lr: 1.0000e-05 - 81ms/epoch - 14ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 0.1761 - accuracy: 0.7453 - mse: 0.1761 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 0.1643 - accuracy: 0.8075 - mse: 0.1643 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 0.1604 - accuracy: 0.7826 - mse: 0.1604 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 0.1541 - accuracy: 0.8137 - mse: 0.1541 - lr: 1.0000e-05 - 87ms/epoch - 14ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 0.1670 - accuracy: 0.7764 - mse: 0.1670 - lr: 1.0000e-05 - 84ms/epoch - 14ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 0.1662 - accuracy: 0.8199 - mse: 0.1662 - lr: 1.0000e-05 - 82ms/epoch - 14ms/step
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2461 - accuracy: 0.6111 - mse: 0.2461
# 2/2 [==============================] - 0s 4ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_4\assets
# INFO:tensorflow:Assets written to: LSTM_4\assets
# Accuracy: 0.6111
# Loss: 0.2460888773202896
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_28 (LSTM)              (None, 128)               113152
#
#  dense_28 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 113,410
# Trainable params: 113,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 6/6 - 4s - loss: 0.3458 - accuracy: 0.5494 - mse: 0.3458 - lr: 0.0010 - 4s/epoch - 634ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.2427 - accuracy: 0.5926 - mse: 0.2427 - lr: 0.0010 - 106ms/epoch - 18ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.2340 - accuracy: 0.6235 - mse: 0.2340 - lr: 0.0010 - 98ms/epoch - 16ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.2276 - accuracy: 0.6173 - mse: 0.2276 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.2251 - accuracy: 0.6728 - mse: 0.2251 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.2153 - accuracy: 0.7160 - mse: 0.2153 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.2078 - accuracy: 0.6975 - mse: 0.2078 - lr: 0.0010 - 94ms/epoch - 16ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.2024 - accuracy: 0.7222 - mse: 0.2024 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.1972 - accuracy: 0.7284 - mse: 0.1972 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.2000 - accuracy: 0.7222 - mse: 0.2000 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.1925 - accuracy: 0.7407 - mse: 0.1925 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.1781 - accuracy: 0.7840 - mse: 0.1781 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.1956 - accuracy: 0.6852 - mse: 0.1956 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.1804 - accuracy: 0.7531 - mse: 0.1804 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.1822 - accuracy: 0.7407 - mse: 0.1822 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.1772 - accuracy: 0.7469 - mse: 0.1772 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.1853 - accuracy: 0.7284 - mse: 0.1853 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.1758 - accuracy: 0.7716 - mse: 0.1758 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.1692 - accuracy: 0.7716 - mse: 0.1692 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.1698 - accuracy: 0.7778 - mse: 0.1698 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 0.1848 - accuracy: 0.7469 - mse: 0.1848 - lr: 0.0010 - 81ms/epoch - 13ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 0.1679 - accuracy: 0.7840 - mse: 0.1679 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 0.1830 - accuracy: 0.7593 - mse: 0.1830 - lr: 1.0000e-05 - 88ms/epoch - 15ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 0.1770 - accuracy: 0.8025 - mse: 0.1770 - lr: 1.0000e-05 - 87ms/epoch - 14ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 0.1800 - accuracy: 0.7778 - mse: 0.1800 - lr: 1.0000e-05 - 91ms/epoch - 15ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 0.1794 - accuracy: 0.7963 - mse: 0.1794 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 0.1702 - accuracy: 0.8148 - mse: 0.1702 - lr: 1.0000e-05 - 84ms/epoch - 14ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 0.1729 - accuracy: 0.8086 - mse: 0.1729 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 0.1626 - accuracy: 0.8210 - mse: 0.1626 - lr: 1.0000e-05 - 86ms/epoch - 14ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 0.1751 - accuracy: 0.7593 - mse: 0.1751 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 0.1745 - accuracy: 0.7593 - mse: 0.1745 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 0.1621 - accuracy: 0.7901 - mse: 0.1621 - lr: 1.0000e-05 - 87ms/epoch - 14ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 0.1729 - accuracy: 0.7593 - mse: 0.1729 - lr: 1.0000e-05 - 87ms/epoch - 14ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 0.1783 - accuracy: 0.7160 - mse: 0.1783 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 0.1593 - accuracy: 0.8025 - mse: 0.1593 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 0.1666 - accuracy: 0.7593 - mse: 0.1666 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 0.1552 - accuracy: 0.8086 - mse: 0.1552 - lr: 1.0000e-05 - 84ms/epoch - 14ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 0.1721 - accuracy: 0.7654 - mse: 0.1721 - lr: 1.0000e-05 - 88ms/epoch - 15ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 0.1605 - accuracy: 0.7778 - mse: 0.1605 - lr: 1.0000e-05 - 88ms/epoch - 15ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 0.1595 - accuracy: 0.7716 - mse: 0.1595 - lr: 1.0000e-07 - 85ms/epoch - 14ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 0.1689 - accuracy: 0.7654 - mse: 0.1689 - lr: 1.0000e-07 - 88ms/epoch - 15ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 0.1661 - accuracy: 0.7593 - mse: 0.1661 - lr: 1.0000e-07 - 81ms/epoch - 13ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 0.1619 - accuracy: 0.7778 - mse: 0.1619 - lr: 1.0000e-07 - 88ms/epoch - 15ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 0.1637 - accuracy: 0.7654 - mse: 0.1637 - lr: 1.0000e-07 - 141ms/epoch - 24ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 0.1557 - accuracy: 0.8086 - mse: 0.1557 - lr: 1.0000e-07 - 88ms/epoch - 15ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 0.1673 - accuracy: 0.7840 - mse: 0.1673 - lr: 1.0000e-07 - 87ms/epoch - 14ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 0.1597 - accuracy: 0.7778 - mse: 0.1597 - lr: 1.0000e-07 - 85ms/epoch - 14ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 0.1641 - accuracy: 0.7593 - mse: 0.1641 - lr: 1.0000e-07 - 86ms/epoch - 14ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 0.1667 - accuracy: 0.7778 - mse: 0.1667 - lr: 1.0000e-07 - 85ms/epoch - 14ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 0.1587 - accuracy: 0.7901 - mse: 0.1587 - lr: 1.0000e-09 - 88ms/epoch - 15ms/step
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2441 - accuracy: 0.5000 - mse: 0.2441
# 2/2 [==============================] - 0s 4ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_4\assets
# INFO:tensorflow:Assets written to: LSTM_4\assets
# Accuracy: 0.5
# Loss: 0.24413511157035828
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_29 (LSTM)              (None, 128)               113152
#
#  dense_29 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 113,410
# Trainable params: 113,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 6/6 - 3s - loss: 0.3535 - accuracy: 0.5000 - mse: 0.3535 - lr: 0.0010 - 3s/epoch - 526ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.2603 - accuracy: 0.5741 - mse: 0.2603 - lr: 0.0010 - 93ms/epoch - 16ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.2487 - accuracy: 0.5864 - mse: 0.2487 - lr: 0.0010 - 93ms/epoch - 16ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.2448 - accuracy: 0.5864 - mse: 0.2448 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.2415 - accuracy: 0.5988 - mse: 0.2415 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.2313 - accuracy: 0.6049 - mse: 0.2313 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.2337 - accuracy: 0.5988 - mse: 0.2337 - lr: 0.0010 - 95ms/epoch - 16ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.2340 - accuracy: 0.6049 - mse: 0.2340 - lr: 0.0010 - 121ms/epoch - 20ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.2258 - accuracy: 0.6358 - mse: 0.2258 - lr: 0.0010 - 96ms/epoch - 16ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.2248 - accuracy: 0.6420 - mse: 0.2248 - lr: 0.0010 - 100ms/epoch - 17ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.2192 - accuracy: 0.6296 - mse: 0.2192 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.2286 - accuracy: 0.6296 - mse: 0.2286 - lr: 0.0010 - 98ms/epoch - 16ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.2217 - accuracy: 0.6543 - mse: 0.2217 - lr: 0.0010 - 118ms/epoch - 20ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.2184 - accuracy: 0.6481 - mse: 0.2184 - lr: 0.0010 - 106ms/epoch - 18ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.2105 - accuracy: 0.6852 - mse: 0.2105 - lr: 0.0010 - 113ms/epoch - 19ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.2095 - accuracy: 0.6790 - mse: 0.2095 - lr: 0.0010 - 102ms/epoch - 17ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.2019 - accuracy: 0.7222 - mse: 0.2019 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.2024 - accuracy: 0.7346 - mse: 0.2024 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.1990 - accuracy: 0.7037 - mse: 0.1990 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.1978 - accuracy: 0.7346 - mse: 0.1978 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 0.2057 - accuracy: 0.6975 - mse: 0.2057 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 0.1895 - accuracy: 0.7284 - mse: 0.1895 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 0.2042 - accuracy: 0.6914 - mse: 0.2042 - lr: 0.0010 - 91ms/epoch - 15ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 0.1973 - accuracy: 0.7160 - mse: 0.1973 - lr: 0.0010 - 96ms/epoch - 16ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 0.1901 - accuracy: 0.7099 - mse: 0.1901 - lr: 0.0010 - 97ms/epoch - 16ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 0.1960 - accuracy: 0.7160 - mse: 0.1960 - lr: 0.0010 - 101ms/epoch - 17ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 0.1958 - accuracy: 0.7160 - mse: 0.1958 - lr: 0.0010 - 95ms/epoch - 16ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 0.1903 - accuracy: 0.7099 - mse: 0.1903 - lr: 0.0010 - 95ms/epoch - 16ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 0.2131 - accuracy: 0.6914 - mse: 0.2131 - lr: 1.0000e-05 - 86ms/epoch - 14ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 0.2147 - accuracy: 0.6914 - mse: 0.2147 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 0.1953 - accuracy: 0.6852 - mse: 0.1953 - lr: 1.0000e-05 - 88ms/epoch - 15ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 0.2019 - accuracy: 0.6852 - mse: 0.2019 - lr: 1.0000e-05 - 87ms/epoch - 14ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 0.2046 - accuracy: 0.6914 - mse: 0.2046 - lr: 1.0000e-05 - 84ms/epoch - 14ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 0.2045 - accuracy: 0.6975 - mse: 0.2045 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 0.1956 - accuracy: 0.7222 - mse: 0.1956 - lr: 1.0000e-05 - 88ms/epoch - 15ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 0.1993 - accuracy: 0.7099 - mse: 0.1993 - lr: 1.0000e-05 - 161ms/epoch - 27ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 0.1893 - accuracy: 0.7099 - mse: 0.1893 - lr: 1.0000e-05 - 93ms/epoch - 15ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 0.2002 - accuracy: 0.6852 - mse: 0.2002 - lr: 1.0000e-05 - 90ms/epoch - 15ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 0.1905 - accuracy: 0.7346 - mse: 0.1905 - lr: 1.0000e-07 - 89ms/epoch - 15ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 0.1967 - accuracy: 0.7099 - mse: 0.1967 - lr: 1.0000e-07 - 84ms/epoch - 14ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 0.1953 - accuracy: 0.7037 - mse: 0.1953 - lr: 1.0000e-07 - 84ms/epoch - 14ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 0.2000 - accuracy: 0.6790 - mse: 0.2000 - lr: 1.0000e-07 - 83ms/epoch - 14ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 0.1911 - accuracy: 0.7160 - mse: 0.1911 - lr: 1.0000e-07 - 86ms/epoch - 14ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 0.1948 - accuracy: 0.7099 - mse: 0.1948 - lr: 1.0000e-07 - 85ms/epoch - 14ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 0.1911 - accuracy: 0.7160 - mse: 0.1911 - lr: 1.0000e-07 - 85ms/epoch - 14ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 0.1890 - accuracy: 0.7037 - mse: 0.1890 - lr: 1.0000e-07 - 82ms/epoch - 14ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 0.1939 - accuracy: 0.7099 - mse: 0.1939 - lr: 1.0000e-07 - 88ms/epoch - 15ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 0.1901 - accuracy: 0.7222 - mse: 0.1901 - lr: 1.0000e-07 - 82ms/epoch - 14ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 0.1874 - accuracy: 0.7037 - mse: 0.1874 - lr: 1.0000e-09 - 86ms/epoch - 14ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 0.1934 - accuracy: 0.6975 - mse: 0.1934 - lr: 1.0000e-09 - 85ms/epoch - 14ms/step
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2190 - accuracy: 0.6944 - mse: 0.2190
# 2/2 [==============================] - 0s 4ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_4\assets
# INFO:tensorflow:Assets written to: LSTM_4\assets
# Accuracy: 0.6944
# Loss: 0.2190314084291458
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_30 (LSTM)              (None, 128)               113152
#
#  dense_30 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 113,410
# Trainable params: 113,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 6/6 - 4s - loss: 0.3403 - accuracy: 0.4938 - mse: 0.3403 - lr: 0.0010 - 4s/epoch - 626ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.2632 - accuracy: 0.5432 - mse: 0.2632 - lr: 0.0010 - 107ms/epoch - 18ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.2379 - accuracy: 0.5432 - mse: 0.2379 - lr: 0.0010 - 93ms/epoch - 16ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.2373 - accuracy: 0.5617 - mse: 0.2373 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.2324 - accuracy: 0.5741 - mse: 0.2324 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.2254 - accuracy: 0.6420 - mse: 0.2254 - lr: 0.0010 - 94ms/epoch - 16ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.2250 - accuracy: 0.6481 - mse: 0.2250 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.2167 - accuracy: 0.6914 - mse: 0.2167 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.2135 - accuracy: 0.6543 - mse: 0.2135 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.2138 - accuracy: 0.6790 - mse: 0.2138 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.2133 - accuracy: 0.7099 - mse: 0.2133 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.2023 - accuracy: 0.6852 - mse: 0.2023 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.1959 - accuracy: 0.7222 - mse: 0.1959 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.1950 - accuracy: 0.7222 - mse: 0.1950 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.1938 - accuracy: 0.7160 - mse: 0.1938 - lr: 0.0010 - 81ms/epoch - 13ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.1929 - accuracy: 0.7346 - mse: 0.1929 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.2014 - accuracy: 0.7099 - mse: 0.2014 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.1865 - accuracy: 0.7531 - mse: 0.1865 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.1811 - accuracy: 0.7778 - mse: 0.1811 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.1831 - accuracy: 0.7469 - mse: 0.1831 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 0.1838 - accuracy: 0.7469 - mse: 0.1838 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 0.1782 - accuracy: 0.7469 - mse: 0.1782 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 0.1881 - accuracy: 0.6975 - mse: 0.1881 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 0.1736 - accuracy: 0.7531 - mse: 0.1736 - lr: 0.0010 - 130ms/epoch - 22ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 0.1776 - accuracy: 0.7407 - mse: 0.1776 - lr: 0.0010 - 122ms/epoch - 20ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 0.1724 - accuracy: 0.7840 - mse: 0.1724 - lr: 0.0010 - 99ms/epoch - 16ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 0.1759 - accuracy: 0.7222 - mse: 0.1759 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 0.1812 - accuracy: 0.7160 - mse: 0.1812 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 0.1705 - accuracy: 0.7407 - mse: 0.1705 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 0.1726 - accuracy: 0.7531 - mse: 0.1726 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 0.1689 - accuracy: 0.7407 - mse: 0.1689 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 0.1554 - accuracy: 0.7963 - mse: 0.1554 - lr: 0.0010 - 87ms/epoch - 15ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 0.1620 - accuracy: 0.7531 - mse: 0.1620 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 0.1661 - accuracy: 0.7840 - mse: 0.1661 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 0.1617 - accuracy: 0.7284 - mse: 0.1617 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 0.1659 - accuracy: 0.7654 - mse: 0.1659 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 0.1537 - accuracy: 0.8210 - mse: 0.1537 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 0.1654 - accuracy: 0.7716 - mse: 0.1654 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 0.1601 - accuracy: 0.7963 - mse: 0.1601 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 0.1646 - accuracy: 0.7840 - mse: 0.1646 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 0.1590 - accuracy: 0.7654 - mse: 0.1590 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 0.1557 - accuracy: 0.8210 - mse: 0.1557 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 0.1656 - accuracy: 0.7593 - mse: 0.1656 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 0.1656 - accuracy: 0.7593 - mse: 0.1656 - lr: 0.0010 - 81ms/epoch - 13ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 0.1547 - accuracy: 0.7654 - mse: 0.1547 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 0.1702 - accuracy: 0.7593 - mse: 0.1702 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 0.1558 - accuracy: 0.7778 - mse: 0.1558 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 0.1540 - accuracy: 0.8210 - mse: 0.1540 - lr: 1.0000e-05 - 84ms/epoch - 14ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 0.1458 - accuracy: 0.7778 - mse: 0.1458 - lr: 1.0000e-05 - 83ms/epoch - 14ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 0.1708 - accuracy: 0.7407 - mse: 0.1708 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1872 - accuracy: 0.7500 - mse: 0.1872
# 2/2 [==============================] - 0s 4ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_4\assets
# INFO:tensorflow:Assets written to: LSTM_4\assets
# Accuracy: 0.75
# Loss: 0.1871820092201233
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_31 (LSTM)              (None, 128)               113152
#
#  dense_31 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 113,410
# Trainable params: 113,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 6/6 - 3s - loss: 0.3337 - accuracy: 0.5062 - mse: 0.3337 - lr: 0.0010 - 3s/epoch - 522ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.2574 - accuracy: 0.4938 - mse: 0.2574 - lr: 0.0010 - 93ms/epoch - 15ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.2491 - accuracy: 0.5679 - mse: 0.2491 - lr: 0.0010 - 97ms/epoch - 16ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.2423 - accuracy: 0.5802 - mse: 0.2423 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.2417 - accuracy: 0.6111 - mse: 0.2417 - lr: 0.0010 - 135ms/epoch - 22ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.2387 - accuracy: 0.5926 - mse: 0.2387 - lr: 0.0010 - 90ms/epoch - 15ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.2349 - accuracy: 0.6235 - mse: 0.2349 - lr: 0.0010 - 92ms/epoch - 15ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.2300 - accuracy: 0.6358 - mse: 0.2300 - lr: 0.0010 - 94ms/epoch - 16ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.2296 - accuracy: 0.5988 - mse: 0.2296 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.2208 - accuracy: 0.6667 - mse: 0.2208 - lr: 0.0010 - 178ms/epoch - 30ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.2270 - accuracy: 0.6235 - mse: 0.2270 - lr: 0.0010 - 93ms/epoch - 16ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.2209 - accuracy: 0.6667 - mse: 0.2209 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.2216 - accuracy: 0.6790 - mse: 0.2216 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.2139 - accuracy: 0.7037 - mse: 0.2139 - lr: 0.0010 - 81ms/epoch - 13ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.2183 - accuracy: 0.6543 - mse: 0.2183 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.2102 - accuracy: 0.6790 - mse: 0.2102 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.2153 - accuracy: 0.7037 - mse: 0.2153 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.2130 - accuracy: 0.6790 - mse: 0.2130 - lr: 0.0010 - 89ms/epoch - 15ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.2008 - accuracy: 0.7160 - mse: 0.2008 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.2034 - accuracy: 0.6790 - mse: 0.2034 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 0.2070 - accuracy: 0.6543 - mse: 0.2070 - lr: 0.0010 - 87ms/epoch - 15ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 0.1980 - accuracy: 0.6914 - mse: 0.1980 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 0.2091 - accuracy: 0.6420 - mse: 0.2091 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 0.2174 - accuracy: 0.6914 - mse: 0.2174 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 0.1955 - accuracy: 0.7222 - mse: 0.1955 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 0.2006 - accuracy: 0.6852 - mse: 0.2006 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 0.1978 - accuracy: 0.7284 - mse: 0.1978 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 0.1989 - accuracy: 0.7099 - mse: 0.1989 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 0.1985 - accuracy: 0.7407 - mse: 0.1985 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 0.1948 - accuracy: 0.7099 - mse: 0.1948 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 0.1948 - accuracy: 0.7099 - mse: 0.1948 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 0.1988 - accuracy: 0.6975 - mse: 0.1988 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 0.1837 - accuracy: 0.7346 - mse: 0.1837 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 0.1953 - accuracy: 0.7222 - mse: 0.1953 - lr: 0.0010 - 87ms/epoch - 14ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 0.1934 - accuracy: 0.7407 - mse: 0.1934 - lr: 0.0010 - 87ms/epoch - 15ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 0.1936 - accuracy: 0.7037 - mse: 0.1936 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 0.1795 - accuracy: 0.7778 - mse: 0.1795 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 0.1804 - accuracy: 0.7531 - mse: 0.1804 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 0.1972 - accuracy: 0.6852 - mse: 0.1972 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 0.1836 - accuracy: 0.7099 - mse: 0.1836 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 0.1755 - accuracy: 0.7778 - mse: 0.1755 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 0.1860 - accuracy: 0.7716 - mse: 0.1860 - lr: 0.0010 - 86ms/epoch - 14ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 0.1816 - accuracy: 0.7716 - mse: 0.1816 - lr: 0.0010 - 88ms/epoch - 15ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 0.1979 - accuracy: 0.7160 - mse: 0.1979 - lr: 0.0010 - 84ms/epoch - 14ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 0.1889 - accuracy: 0.7099 - mse: 0.1889 - lr: 0.0010 - 82ms/epoch - 14ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 0.1773 - accuracy: 0.7531 - mse: 0.1773 - lr: 0.0010 - 85ms/epoch - 14ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 0.1833 - accuracy: 0.7284 - mse: 0.1833 - lr: 0.0010 - 83ms/epoch - 14ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 0.1916 - accuracy: 0.6728 - mse: 0.1916 - lr: 1.0000e-05 - 87ms/epoch - 15ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 0.1903 - accuracy: 0.7284 - mse: 0.1903 - lr: 1.0000e-05 - 86ms/epoch - 14ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 0.1849 - accuracy: 0.7284 - mse: 0.1849 - lr: 1.0000e-05 - 85ms/epoch - 14ms/step
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2493 - accuracy: 0.6944 - mse: 0.2493
# 2/2 [==============================] - 0s 4ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_4\assets
# INFO:tensorflow:Assets written to: LSTM_4\assets
# Accuracy: 0.6944
# Loss: 0.24925729632377625

# %%
results = pd.DataFrame(data = [results_2012[:2],results_2013[:2],results_2014[:2],results_2015[:2],results_2016[:2],
                               results_2017[:2],results_2018[:2],results_2019[:2]],
                            index = ['2012', '2013', '2014','2015','2016','2017','2018','2019'],
                            columns = ['loss', 'accuracy'])
sum(results['accuracy'])/8
# Out:
# 0.6597222164273262

# %%
def build_conf_matrix(prediction, true):
    s = 0
    pl = []
    for pred in prediction:
        if pred[0] > pred[1]:
            pl.append(0)
        else:
            pl.append(1)

    for i in range(len(pl)):
        if pl[i] == true.values[i]:
            s+=1

    c_train = confusion_matrix(true, pl)
    disp = ConfusionMatrixDisplay(c_train)
    return disp

cf_2012 = build_conf_matrix(pred_2012, y_valid_2012)
cf_2013 = build_conf_matrix(pred_2013, y_valid_2013)
cf_2014 = build_conf_matrix(pred_2014, y_valid_2014)
cf_2015 = build_conf_matrix(pred_2015, y_valid_2015)
cf_2016 = build_conf_matrix(pred_2016, y_valid_2016)
cf_2017 = build_conf_matrix(pred_2017, y_valid_2017)
cf_2018 = build_conf_matrix(pred_2018, y_valid_2018)
cf_2019 = build_conf_matrix(pred_2019, y_valid_2019)


fig, ax = plt.subplots(3,3)
fig.set_figwidth(10)
fig.set_figheight(12)
fig.suptitle("Confusion Matrices: LSTM Model 4 Training/Validation Set 65.9%")
cf_2012.plot(ax=ax[0][0]), cf_2013.plot(ax=ax[0][1]), cf_2014.plot(ax=ax[0][2])
cf_2015.plot(ax=ax[1][0]), cf_2016.plot(ax=ax[1][1]), cf_2017.plot(ax=ax[1][2])
cf_2018.plot(ax=ax[2][0]), cf_2019.plot(ax=ax[2][1])

ax[0][0].set_title(2012), ax[0][1].set_title(2013), ax[0][2].set_title(2014)
ax[1][0].set_title(2015), ax[1][1].set_title(2016), ax[1][2].set_title(2017)
ax[2][0].set_title(2018), ax[2][1].set_title(2019)
# Out:
# (Text(0.5, 1.0, '2018'), Text(0.5, 1.0, '2019'))

# %% [markdown]
# Res_1 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.25, recurrent_dropout = 0.25, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_2 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'sigmoid' , dropout = 0.25, recurrent_dropout = 0.25, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_3 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.25, recurrent_dropout = 0.25, return_sequences=True))
#     model.add(LSTM( 64, activation='tanh ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_4 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.2, recurrent_dropout = 0.2, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_5 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
#
# Res_6 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.4, recurrent_dropout = 0.4, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_7 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3, return_sequences=True))
#     model.add(LSTM( 64, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(64, activation="tanh))
#     model.add(Dense(2, activation="tanh"))
#
# Res_8 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3, return_sequences=True))
#     model.add(LSTM( 64, return_sequences=True, dropout = 0.3))
#     model.add(LSTM( 64 ))
#     model.add(Dense(32, activation="tanh))
#     model.add(Dense(2, activation="tanh"))
#
# Res_10 = model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3, return_sequences=True))
#     model.add(LSTM( 64, return_sequences=True, dropout=0.3))
#     model.add(LSTM( 32, return_sequences=True, dropout= .1 ))
#     model.add(LSTM( 16, return_sequences=True ))
#     model.add(Dense(8))
#     model.add(LSTM( 32 ))
#     # model.add(LSTM( 64 ))
#     model.add(Dense(32, activation="tanh"))
#     model.add(Dense(16, activation="tanh"))
#     model.add(Dense(2, activation="tanh"))

# %%
loss = train_history.history['loss']
# validation_loss = train_history.history['val_loss']
accuracy = train_history.history['accuracy']
# val_accuracy = train_history.history['val_accuracy']

fig = plt.gcf()
fig.set_size_inches(18.5, 5.5)
plt.subplot(1,2,1)
plt.plot(loss)
plt.plot(validation_loss)
plt.legend(['loss', 'validation_loss'])
plt.subplot(1,2,2)
plt.plot(accuracy)
plt.plot(val_accuracy)
plt.legend(['accuracy', 'validation_accuracy'])
plt.show()
