# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,roc_auc_score,confusion_matrix,accuracy_score,f1_score,roc_curve, ConfusionMatrixDisplay
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler

from keras.models import Sequential
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.layers import Dense, Embedding, LSTM
from keras.utils import to_categorical

from IPython.display import display
import random
import matplotlib.pyplot as plt
# random.seed(10)

# %%
# Import Data
games_folder_path = "C:/Users/Craig/Documents/Thesis/Thomas_Gallagher_Thesis/Data/AFL_Stats_sorted/Year/Games/"
games_2012 = pd.read_csv(games_folder_path + '2012.csv', index_col=False, parse_dates=['date'])
games_2013 = pd.read_csv(games_folder_path + '2013.csv', index_col=False, parse_dates=['date'])
games_2014 = pd.read_csv(games_folder_path + '2014.csv', index_col=False, parse_dates=['date'])
games_2015 = pd.read_csv(games_folder_path + '2015.csv', index_col=False, parse_dates=['date'])
games_2016 = pd.read_csv(games_folder_path + '2016.csv', index_col=False, parse_dates=['date'])
games_2017 = pd.read_csv(games_folder_path + '2017.csv', index_col=False, parse_dates=['date'])
games_2018 = pd.read_csv(games_folder_path + '2018.csv', index_col=False, parse_dates=['date'])
games_2019 = pd.read_csv(games_folder_path + '2019.csv', index_col=False, parse_dates=['date'])
games_2020 = pd.read_csv(games_folder_path + '2020.csv', index_col=False, parse_dates=['date'])
games_2021 = pd.read_csv(games_folder_path + '2021.csv', index_col=False, parse_dates=['date'])


all_games = pd.read_csv(games_folder_path + 'games_sorted.csv', index_col=False, parse_dates=['date'])
# Out:
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2012 = pd.read_csv(games_folder_path + '2012.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2013 = pd.read_csv(games_folder_path + '2013.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2014 = pd.read_csv(games_folder_path + '2014.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2015 = pd.read_csv(games_folder_path + '2015.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2016 = pd.read_csv(games_folder_path + '2016.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:8: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2017 = pd.read_csv(games_folder_path + '2017.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:9: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2018 = pd.read_csv(games_folder_path + '2018.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:10: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2019 = pd.read_csv(games_folder_path + '2019.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:11: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2020 = pd.read_csv(games_folder_path + '2020.csv', index_col=False, parse_dates=['date'])
# C:\Users\Craig\AppData\Local\Temp\ipykernel_10332\3458396436.py:12: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   games_2021 = pd.read_csv(games_folder_path + '2021.csv', index_col=False, parse_dates=['date'])

# %%
# One Hot Encoding Teams
encoding = LabelEncoder()
encoding.fit(all_games["homeTeam"].values)


def OHE_Teams(games):
    home_teams = encoding.transform(games["homeTeam"].values)
    away_teams = encoding.transform(games["awayTeam"].values)

    all_teams = np.vstack([home_teams, away_teams]).T
 
    oneHot = OneHotEncoder()
    X_teams = oneHot.fit_transform(all_teams).todense()
    X_teams = pd.DataFrame(X_teams)
    games = pd.concat([games, pd.DataFrame(X_teams)],axis=1)
    return games

games_2012 = OHE_Teams(games_2012)
games_2013 = OHE_Teams(games_2013)
games_2014 = OHE_Teams(games_2014)
games_2015 = OHE_Teams(games_2015)
games_2016 = OHE_Teams(games_2016)
games_2017 = OHE_Teams(games_2017)
games_2018 = OHE_Teams(games_2018)
games_2019 = OHE_Teams(games_2019)
games_2020 = OHE_Teams(games_2020)
games_2021 = OHE_Teams(games_2021)

all_games = OHE_Teams(all_games)

# %%
# One Hot Encoding Venues
encoding = LabelEncoder()
encoding.fit(all_games["venue"].values)
all_venues = all_games["venue"].values

all_venues = all_venues.reshape(-1,1)

def OHE_Venues(games):
    venues = games['venue'].values
    # all_venues = all_venues.reshape(-1,1)
    venues = venues.reshape(-1,1)
    oneHot = OneHotEncoder()

    oneHot.fit(all_venues)
    X_venues = oneHot.transform(venues).toarray()
    X_venues = pd.DataFrame(X_venues, columns=oneHot.categories_[0])
    games = pd.concat([games, X_venues], axis=1)
    return games

games_2012 = OHE_Venues(games_2012)
games_2013 = OHE_Venues(games_2013)
games_2014 = OHE_Venues(games_2014)
games_2015 = OHE_Venues(games_2015)
games_2016 = OHE_Venues(games_2016)
games_2017 = OHE_Venues(games_2017)
games_2018 = OHE_Venues(games_2018)
games_2019 = OHE_Venues(games_2019)
games_2020 = OHE_Venues(games_2020)
games_2021 = OHE_Venues(games_2021)

all_games = OHE_Venues(all_games)

# %%
def split_time(row):
    time = row['startTime']
    time = time.split(':')
    time = ''.join(time[:2])
    row['startTime'] = time
    return row

games_2012 = games_2012.apply(split_time, axis=1)
games_2013 = games_2013.apply(split_time, axis=1)
games_2014 = games_2014.apply(split_time, axis=1)
games_2015 = games_2015.apply(split_time, axis=1)
games_2016 = games_2016.apply(split_time, axis=1)
games_2017 = games_2017.apply(split_time, axis=1)
games_2018 = games_2018.apply(split_time, axis=1)
games_2019 = games_2019.apply(split_time, axis=1)
games_2020 = games_2020.apply(split_time, axis=1)
games_2021 = games_2021.apply(split_time, axis=1)

# %%
y_true_2012 = games_2012['homeWin']
y_true_2013 = games_2013['homeWin']
y_true_2014 = games_2014['homeWin']
y_true_2015 = games_2015['homeWin']
y_true_2016 = games_2016['homeWin']
y_true_2017 = games_2017['homeWin']
y_true_2018 = games_2018['homeWin']
y_true_2019 = games_2019['homeWin']
y_true_2020 = games_2020['homeWin']
y_true_2021 = games_2021['homeWin']
y_true = all_games['homeWin']

drop_values = ['gameId', 'venue', 'homeWin', 'homeTeam', 'awayTeam', 'year','date', 'homeTeamScore', 'awayTeamScore', 'round']

def drop_columns(game_list):
    game_list = game_list.drop(drop_values,axis=1)
    game_list.columns = game_list.columns.astype(str)
    return game_list

games_2012 = drop_columns(games_2012)
games_2013 = drop_columns(games_2013)
games_2014 = drop_columns(games_2014)
games_2015 = drop_columns(games_2015)
games_2016 = drop_columns(games_2016)
games_2017 = drop_columns(games_2017)
games_2018 = drop_columns(games_2018)
games_2019 = drop_columns(games_2019)
games_2020 = drop_columns(games_2020)
games_2021 = drop_columns(games_2021)

all_games = drop_columns(all_games)

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
games_2012 = scaler.fit_transform(games_2012)
games_2013 = scaler.fit_transform(games_2013)
games_2014 = scaler.fit_transform(games_2014)
games_2015 = scaler.fit_transform(games_2015)
games_2016 = scaler.fit_transform(games_2016)
games_2017 = scaler.fit_transform(games_2017)
games_2018 = scaler.fit_transform(games_2018)
games_2019 = scaler.fit_transform(games_2019)
games_2020 = scaler.fit_transform(games_2020)
games_2021 = scaler.fit_transform(games_2021)

# %%
y_train_2012 = y_true_2012[27:171]
y_valid_2012 = y_true_2012[171:]

y_train_2013 = y_true_2013[27:171]
y_valid_2013 = y_true_2013[171:]

y_train_2014 = y_true_2014[27:171]
y_valid_2014 = y_true_2014[171:]

y_train_2015 = y_true_2015[27:170]
y_valid_2015 = y_true_2015[170:]

y_train_2016 = y_true_2016[27:171]
y_valid_2016 = y_true_2016[171:]

y_train_2017 = y_true_2017[27:171]
y_valid_2017 = y_true_2017[171:]

y_train_2018 = y_true_2018[27:171]
y_valid_2018 = y_true_2018[171:]

y_train_2019 = y_true_2019[27:171]
y_valid_2019 = y_true_2019[171:]

y_train_2020 = y_true_2020[27:127]
y_valid_2020 = y_true_2020[127:]

y_train_2021 = y_true_2021[27:171]
y_valid_2021 = y_true_2021[171:]

y_train = y_true[:1447]
y_valid = y_true[1447:1655]

# %%
# OHE Y values
oneHot = OneHotEncoder()
def OHE_y_values(y_val):
    y = np.vstack([y_val]).T
    
    # for i in range(len(y)):
    #     if y[i] == 1:
    #         y[i] = 0

    y_OHE = oneHot.fit_transform(y).toarray()

    return y_OHE


y_train_2012_OHE = OHE_y_values(y_train_2012)
y_valid_2012_OHE = OHE_y_values(y_valid_2012)

y_train_2013_OHE = OHE_y_values(y_train_2013)
y_valid_2013_OHE = OHE_y_values(y_valid_2013)

y_train_2014_OHE = OHE_y_values(y_train_2014)
y_valid_2014_OHE = OHE_y_values(y_valid_2014)

y_train_2015_OHE = OHE_y_values(y_train_2015)
y_valid_2015_OHE = OHE_y_values(y_valid_2015)

y_train_2016_OHE = OHE_y_values(y_train_2016)
y_valid_2016_OHE = OHE_y_values(y_valid_2016)

y_train_2017_OHE = OHE_y_values(y_train_2017)
y_valid_2017_OHE = OHE_y_values(y_valid_2017)

y_train_2018_OHE = OHE_y_values(y_train_2018)
y_valid_2018_OHE = OHE_y_values(y_valid_2018)

y_train_2019_OHE = OHE_y_values(y_train_2019)
y_valid_2019_OHE = OHE_y_values(y_valid_2019)

y_train_2020_OHE = OHE_y_values(y_train_2020)
y_valid_2020_OHE = OHE_y_values(y_valid_2020)

y_train_2021_OHE = OHE_y_values(y_train_2021)
y_valid_2021_OHE = OHE_y_values(y_valid_2021)

y_train_OHE = OHE_y_values(y_train)
y_valid_OHE = OHE_y_values(y_valid)

# %%
def set_window(games):
    y = 0 #
    p = 0 # round 0
    # d_full = np.zeros(shape=(1980,75))
    d_full = np.zeros(shape=(5040,92)) # (207 - 18) * 18 + (207 - 18)
    for x in range(0,d_full.shape[0],28): # For games in each round corresponds to d_full, when a round is ended it jumps over the added games
        y = 27 # link to previous rounds
        if x % 252 == 0: # Games in each round * added games
            p += 1 # move to next round when 90 index is reached
        for i in range(27): # fills out the first 18 posistions in the window with previous games
            d_full[x+i] = games[p+i] # at pos x add corresponding previous game
        d_full[x+y] = games[x//28 + y] # add game in question to final position
    
    d_Train = d_full[:4032]
    d_valid = d_full[4032:]
    d_Train = np.reshape(d_Train, (144, 28,92))
    d_valid = np.reshape(d_valid, (36, 28, 92))
    return d_Train, d_valid

x_train_2012, x_valid_2012 = set_window(games_2012)
x_train_2013, x_valid_2013 = set_window(games_2013)
x_train_2014, x_valid_2014 = set_window(games_2014)
# x_train_2015, x_valid_2015 = set_window(games_2015)
x_train_2016, x_valid_2016 = set_window(games_2016)
x_train_2017, x_valid_2017 = set_window(games_2017)
x_train_2018, x_valid_2018 = set_window(games_2018)
x_train_2019, x_valid_2019 = set_window(games_2019)
# x_train_2020, x_valid_2020 = set_window(games_2020)

# %%
def set_window_2015(games):
    y = 0
    p = 0
    d_full = np.zeros(shape=(5012,92))
    for x in range(0,d_full.shape[0],28): # Goes through index for each round
        y = 27 # link to previous round
        if x % 252 == 0:
            p += 1 # move to next round when 90 index is reached
        for i in range(27): # fills out the first nine posistions in the window with previous games
                d_full[x+i] = games[p+i] # at pos x add corresponding previous game
            
        d_full[x+y] = games[x//28 + y] # add game in question to final position
        
    d_Train = d_full[:4004]
    d_valid = d_full[4004:]
    d_Train = np.reshape(d_Train, (143, 28,92))
    d_valid = np.reshape(d_valid, (36, 28, 92))
    return d_Train, d_valid

x_train_2015, x_valid_2015 = set_window_2015(games_2015)

# %%
def train_model_6( xTrain, yTrain, xValid , yValid):
    random.seed(26)
    model = Sequential()
    model.add(LSTM( 32 ,input_shape = (28,92), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3))
    model.add(Dense(2, activation="tanh"))
    model.build()   
    model.summary()
    model.compile( optimizer = "rmsprop" , loss = 'mean_squared_error' , metrics = ['accuracy', 'mse'])

    reduce_lr = ReduceLROnPlateau( monitor = 'accuracy', factor = 0.01, patience=10, cooldown=0)
    
    callbacks = [ reduce_lr ]
    model.fit( xTrain, yTrain , epochs = 50, shuffle=False, callbacks=callbacks, verbose = 2)

    # train_history = model.fit( x_train_2012 , y_train_2012 , epochs = 10, validation_split = 0.1 , verbose = 1 )
    score = model.evaluate( xValid , yValid )
    pred = model.predict(xValid)
    model.save("LSTM_6")
    # print( f"Train Accuracy: {train_history.history}" )
    
    print( "Accuracy: {:0.4}".format( score[1] ))
    print( "Loss:", score[0] )
    return score, pred

# %%
results_2012, pred_2012 = train_model_6(x_train_2012, y_train_2012_OHE, x_valid_2012, y_valid_2012_OHE) 
results_2013, pred_2013 = train_model_6(x_train_2013, y_train_2013_OHE, x_valid_2013, y_valid_2013_OHE) 
results_2014, pred_2014 = train_model_6(x_train_2014, y_train_2014_OHE, x_valid_2014, y_valid_2014_OHE) 
results_2015, pred_2015 = train_model_6(x_train_2015, y_train_2015_OHE, x_valid_2015, y_valid_2015_OHE) 
results_2016, pred_2016 = train_model_6(x_train_2016, y_train_2016_OHE, x_valid_2016, y_valid_2016_OHE) 
results_2017, pred_2017 = train_model_6(x_train_2017, y_train_2017_OHE, x_valid_2017, y_valid_2017_OHE) 
results_2018, pred_2018 = train_model_6(x_train_2018, y_train_2018_OHE, x_valid_2018, y_valid_2018_OHE) 
results_2019, pred_2019 = train_model_6(x_train_2019, y_train_2019_OHE, x_valid_2019, y_valid_2019_OHE)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 32)                16000
#
#  dense_16 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 16,066
# Trainable params: 16,066
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 3s - loss: 0.2632 - accuracy: 0.5625 - mse: 0.2632 - lr: 0.0010 - 3s/epoch - 657ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.2515 - accuracy: 0.5486 - mse: 0.2515 - lr: 0.0010 - 104ms/epoch - 21ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.2422 - accuracy: 0.5556 - mse: 0.2422 - lr: 0.0010 - 105ms/epoch - 21ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.2392 - accuracy: 0.5694 - mse: 0.2392 - lr: 0.0010 - 107ms/epoch - 21ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.2339 - accuracy: 0.5833 - mse: 0.2339 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.2266 - accuracy: 0.6319 - mse: 0.2266 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.2305 - accuracy: 0.6042 - mse: 0.2305 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.2265 - accuracy: 0.6042 - mse: 0.2265 - lr: 0.0010 - 104ms/epoch - 21ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.2230 - accuracy: 0.6389 - mse: 0.2230 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.2169 - accuracy: 0.6667 - mse: 0.2169 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.2185 - accuracy: 0.6458 - mse: 0.2185 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.2150 - accuracy: 0.6597 - mse: 0.2150 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.2045 - accuracy: 0.6944 - mse: 0.2045 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.2099 - accuracy: 0.7153 - mse: 0.2099 - lr: 0.0010 - 105ms/epoch - 21ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.2052 - accuracy: 0.6944 - mse: 0.2052 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.1991 - accuracy: 0.7083 - mse: 0.1991 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.1934 - accuracy: 0.7431 - mse: 0.1934 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.1879 - accuracy: 0.7569 - mse: 0.1879 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.2014 - accuracy: 0.6875 - mse: 0.2014 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1884 - accuracy: 0.7569 - mse: 0.1884 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1850 - accuracy: 0.7708 - mse: 0.1850 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1816 - accuracy: 0.8056 - mse: 0.1816 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1849 - accuracy: 0.7778 - mse: 0.1849 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1764 - accuracy: 0.7639 - mse: 0.1764 - lr: 0.0010 - 103ms/epoch - 21ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1812 - accuracy: 0.7431 - mse: 0.1812 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1858 - accuracy: 0.7292 - mse: 0.1858 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1724 - accuracy: 0.7917 - mse: 0.1724 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1616 - accuracy: 0.7778 - mse: 0.1616 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1665 - accuracy: 0.8056 - mse: 0.1665 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1659 - accuracy: 0.8056 - mse: 0.1659 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1659 - accuracy: 0.8125 - mse: 0.1659 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1645 - accuracy: 0.7778 - mse: 0.1645 - lr: 0.0010 - 146ms/epoch - 29ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1694 - accuracy: 0.7708 - mse: 0.1694 - lr: 0.0010 - 104ms/epoch - 21ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1596 - accuracy: 0.7986 - mse: 0.1596 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1433 - accuracy: 0.8542 - mse: 0.1433 - lr: 0.0010 - 104ms/epoch - 21ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1689 - accuracy: 0.7569 - mse: 0.1689 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1526 - accuracy: 0.8056 - mse: 0.1526 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1653 - accuracy: 0.7361 - mse: 0.1653 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1616 - accuracy: 0.7778 - mse: 0.1616 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1544 - accuracy: 0.7708 - mse: 0.1544 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1631 - accuracy: 0.7708 - mse: 0.1631 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1536 - accuracy: 0.7708 - mse: 0.1536 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1569 - accuracy: 0.7778 - mse: 0.1569 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1413 - accuracy: 0.8264 - mse: 0.1413 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1514 - accuracy: 0.7847 - mse: 0.1514 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1516 - accuracy: 0.7917 - mse: 0.1516 - lr: 1.0000e-05 - 189ms/epoch - 38ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1554 - accuracy: 0.7847 - mse: 0.1554 - lr: 1.0000e-05 - 110ms/epoch - 22ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1451 - accuracy: 0.8333 - mse: 0.1451 - lr: 1.0000e-05 - 97ms/epoch - 19ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1439 - accuracy: 0.8264 - mse: 0.1439 - lr: 1.0000e-05 - 98ms/epoch - 20ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1466 - accuracy: 0.8264 - mse: 0.1466 - lr: 1.0000e-05 - 98ms/epoch - 20ms/step
# 2/2 [==============================] - 1s 9ms/step - loss: 0.2540 - accuracy: 0.5556 - mse: 0.2540
# 2/2 [==============================] - 0s 6ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_6\assets
# INFO:tensorflow:Assets written to: LSTM_6\assets
# Accuracy: 0.5556
# Loss: 0.2539900541305542
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_17 (LSTM)              (None, 32)                16000
#
#  dense_17 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 16,066
# Trainable params: 16,066
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 3s - loss: 0.2582 - accuracy: 0.5694 - mse: 0.2582 - lr: 0.0010 - 3s/epoch - 617ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.2318 - accuracy: 0.6389 - mse: 0.2318 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.2309 - accuracy: 0.6458 - mse: 0.2309 - lr: 0.0010 - 107ms/epoch - 21ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.2287 - accuracy: 0.6111 - mse: 0.2287 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.2174 - accuracy: 0.6667 - mse: 0.2174 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.2246 - accuracy: 0.6736 - mse: 0.2246 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.2121 - accuracy: 0.6736 - mse: 0.2121 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.2115 - accuracy: 0.6875 - mse: 0.2115 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.2068 - accuracy: 0.6875 - mse: 0.2068 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.2053 - accuracy: 0.6875 - mse: 0.2053 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.2030 - accuracy: 0.6806 - mse: 0.2030 - lr: 0.0010 - 92ms/epoch - 18ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.1931 - accuracy: 0.7361 - mse: 0.1931 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.1916 - accuracy: 0.7431 - mse: 0.1916 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.1967 - accuracy: 0.7222 - mse: 0.1967 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.1896 - accuracy: 0.7014 - mse: 0.1896 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.1832 - accuracy: 0.7292 - mse: 0.1832 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.1861 - accuracy: 0.7153 - mse: 0.1861 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.1704 - accuracy: 0.7708 - mse: 0.1704 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.1684 - accuracy: 0.8194 - mse: 0.1684 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1733 - accuracy: 0.7569 - mse: 0.1733 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1733 - accuracy: 0.7569 - mse: 0.1733 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1723 - accuracy: 0.7708 - mse: 0.1723 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1738 - accuracy: 0.7708 - mse: 0.1738 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1568 - accuracy: 0.7917 - mse: 0.1568 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1565 - accuracy: 0.7986 - mse: 0.1565 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1667 - accuracy: 0.7639 - mse: 0.1667 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1641 - accuracy: 0.7778 - mse: 0.1641 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1512 - accuracy: 0.8264 - mse: 0.1512 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1557 - accuracy: 0.7986 - mse: 0.1557 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1494 - accuracy: 0.8056 - mse: 0.1494 - lr: 0.0010 - 89ms/epoch - 18ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1559 - accuracy: 0.8333 - mse: 0.1559 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1459 - accuracy: 0.8333 - mse: 0.1459 - lr: 0.0010 - 133ms/epoch - 27ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1523 - accuracy: 0.7917 - mse: 0.1523 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1446 - accuracy: 0.8194 - mse: 0.1446 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1472 - accuracy: 0.7986 - mse: 0.1472 - lr: 0.0010 - 91ms/epoch - 18ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1482 - accuracy: 0.8403 - mse: 0.1482 - lr: 0.0010 - 90ms/epoch - 18ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1423 - accuracy: 0.8542 - mse: 0.1423 - lr: 0.0010 - 166ms/epoch - 33ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1552 - accuracy: 0.7778 - mse: 0.1552 - lr: 0.0010 - 107ms/epoch - 21ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1504 - accuracy: 0.8125 - mse: 0.1504 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1506 - accuracy: 0.8056 - mse: 0.1506 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1344 - accuracy: 0.8125 - mse: 0.1344 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1524 - accuracy: 0.8125 - mse: 0.1524 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1501 - accuracy: 0.8194 - mse: 0.1501 - lr: 0.0010 - 92ms/epoch - 18ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1473 - accuracy: 0.8056 - mse: 0.1473 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1400 - accuracy: 0.8403 - mse: 0.1400 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1393 - accuracy: 0.8194 - mse: 0.1393 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1436 - accuracy: 0.8542 - mse: 0.1436 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1451 - accuracy: 0.8194 - mse: 0.1451 - lr: 1.0000e-05 - 97ms/epoch - 19ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1432 - accuracy: 0.8125 - mse: 0.1432 - lr: 1.0000e-05 - 97ms/epoch - 19ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1421 - accuracy: 0.8194 - mse: 0.1421 - lr: 1.0000e-05 - 94ms/epoch - 19ms/step
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2455 - accuracy: 0.6111 - mse: 0.2455
# 2/2 [==============================] - 0s 5ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_6\assets
# INFO:tensorflow:Assets written to: LSTM_6\assets
# Accuracy: 0.6111
# Loss: 0.24550111591815948
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 32)                16000
#
#  dense_18 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 16,066
# Trainable params: 16,066
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 3s - loss: 0.2587 - accuracy: 0.5764 - mse: 0.2587 - lr: 0.0010 - 3s/epoch - 615ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.2413 - accuracy: 0.6042 - mse: 0.2413 - lr: 0.0010 - 103ms/epoch - 21ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.2273 - accuracy: 0.6458 - mse: 0.2273 - lr: 0.0010 - 103ms/epoch - 21ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.2336 - accuracy: 0.6111 - mse: 0.2336 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.2210 - accuracy: 0.6944 - mse: 0.2210 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.2305 - accuracy: 0.6181 - mse: 0.2305 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.2184 - accuracy: 0.6597 - mse: 0.2184 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.2095 - accuracy: 0.7431 - mse: 0.2095 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.1999 - accuracy: 0.7361 - mse: 0.1999 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.2026 - accuracy: 0.7569 - mse: 0.2026 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.2117 - accuracy: 0.6667 - mse: 0.2117 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.1968 - accuracy: 0.7569 - mse: 0.1968 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.2000 - accuracy: 0.7292 - mse: 0.2000 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.1978 - accuracy: 0.7431 - mse: 0.1978 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.1843 - accuracy: 0.7917 - mse: 0.1843 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.1877 - accuracy: 0.7569 - mse: 0.1877 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.1763 - accuracy: 0.7639 - mse: 0.1763 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.1824 - accuracy: 0.7292 - mse: 0.1824 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.1737 - accuracy: 0.7778 - mse: 0.1737 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1775 - accuracy: 0.7569 - mse: 0.1775 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1675 - accuracy: 0.7708 - mse: 0.1675 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1829 - accuracy: 0.7639 - mse: 0.1829 - lr: 0.0010 - 90ms/epoch - 18ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1766 - accuracy: 0.7778 - mse: 0.1766 - lr: 0.0010 - 92ms/epoch - 18ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1759 - accuracy: 0.7778 - mse: 0.1759 - lr: 0.0010 - 90ms/epoch - 18ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1811 - accuracy: 0.7708 - mse: 0.1811 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1692 - accuracy: 0.7569 - mse: 0.1692 - lr: 1.0000e-05 - 92ms/epoch - 18ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1704 - accuracy: 0.7222 - mse: 0.1704 - lr: 1.0000e-05 - 155ms/epoch - 31ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1685 - accuracy: 0.7500 - mse: 0.1685 - lr: 1.0000e-05 - 124ms/epoch - 25ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1633 - accuracy: 0.7917 - mse: 0.1633 - lr: 1.0000e-05 - 102ms/epoch - 20ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1685 - accuracy: 0.7639 - mse: 0.1685 - lr: 1.0000e-05 - 150ms/epoch - 30ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1774 - accuracy: 0.7569 - mse: 0.1774 - lr: 1.0000e-05 - 99ms/epoch - 20ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1746 - accuracy: 0.7361 - mse: 0.1746 - lr: 1.0000e-05 - 101ms/epoch - 20ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1768 - accuracy: 0.7569 - mse: 0.1768 - lr: 1.0000e-05 - 96ms/epoch - 19ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1701 - accuracy: 0.7292 - mse: 0.1701 - lr: 1.0000e-05 - 96ms/epoch - 19ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1728 - accuracy: 0.7500 - mse: 0.1728 - lr: 1.0000e-05 - 98ms/epoch - 20ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1681 - accuracy: 0.7708 - mse: 0.1681 - lr: 1.0000e-07 - 103ms/epoch - 21ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1725 - accuracy: 0.7778 - mse: 0.1725 - lr: 1.0000e-07 - 97ms/epoch - 19ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1671 - accuracy: 0.7569 - mse: 0.1671 - lr: 1.0000e-07 - 96ms/epoch - 19ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1645 - accuracy: 0.8056 - mse: 0.1645 - lr: 1.0000e-07 - 99ms/epoch - 20ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1735 - accuracy: 0.7708 - mse: 0.1735 - lr: 1.0000e-07 - 92ms/epoch - 18ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1638 - accuracy: 0.7778 - mse: 0.1638 - lr: 1.0000e-07 - 99ms/epoch - 20ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1626 - accuracy: 0.7847 - mse: 0.1626 - lr: 1.0000e-07 - 102ms/epoch - 20ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1613 - accuracy: 0.7847 - mse: 0.1613 - lr: 1.0000e-07 - 99ms/epoch - 20ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1697 - accuracy: 0.7292 - mse: 0.1697 - lr: 1.0000e-07 - 100ms/epoch - 20ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1712 - accuracy: 0.7569 - mse: 0.1712 - lr: 1.0000e-07 - 92ms/epoch - 18ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1735 - accuracy: 0.7569 - mse: 0.1735 - lr: 1.0000e-07 - 94ms/epoch - 19ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1628 - accuracy: 0.7986 - mse: 0.1628 - lr: 1.0000e-07 - 94ms/epoch - 19ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1756 - accuracy: 0.7222 - mse: 0.1756 - lr: 1.0000e-07 - 95ms/epoch - 19ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1617 - accuracy: 0.7778 - mse: 0.1617 - lr: 1.0000e-07 - 94ms/epoch - 19ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1699 - accuracy: 0.7986 - mse: 0.1699 - lr: 1.0000e-09 - 97ms/epoch - 19ms/step
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2082 - accuracy: 0.7222 - mse: 0.2082
# 2/2 [==============================] - 0s 5ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_6\assets
# INFO:tensorflow:Assets written to: LSTM_6\assets
# Accuracy: 0.7222
# Loss: 0.20822376012802124
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_19 (LSTM)              (None, 32)                16000
#
#  dense_19 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 16,066
# Trainable params: 16,066
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 3s - loss: 0.2841 - accuracy: 0.4755 - mse: 0.2841 - lr: 0.0010 - 3s/epoch - 614ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.2653 - accuracy: 0.5175 - mse: 0.2653 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.2509 - accuracy: 0.5664 - mse: 0.2509 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.2451 - accuracy: 0.5944 - mse: 0.2451 - lr: 0.0010 - 103ms/epoch - 21ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.2354 - accuracy: 0.6434 - mse: 0.2354 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.2348 - accuracy: 0.6224 - mse: 0.2348 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.2399 - accuracy: 0.6434 - mse: 0.2399 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.2289 - accuracy: 0.6713 - mse: 0.2289 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.2283 - accuracy: 0.6853 - mse: 0.2283 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.2244 - accuracy: 0.6434 - mse: 0.2244 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.2243 - accuracy: 0.6503 - mse: 0.2243 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.2206 - accuracy: 0.6783 - mse: 0.2206 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.2135 - accuracy: 0.7203 - mse: 0.2135 - lr: 0.0010 - 104ms/epoch - 21ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.2191 - accuracy: 0.7133 - mse: 0.2191 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.2102 - accuracy: 0.7203 - mse: 0.2102 - lr: 0.0010 - 104ms/epoch - 21ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.2107 - accuracy: 0.7203 - mse: 0.2107 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.1995 - accuracy: 0.7622 - mse: 0.1995 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.2038 - accuracy: 0.6923 - mse: 0.2038 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.1981 - accuracy: 0.7483 - mse: 0.1981 - lr: 0.0010 - 179ms/epoch - 36ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1952 - accuracy: 0.7273 - mse: 0.1952 - lr: 0.0010 - 110ms/epoch - 22ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1943 - accuracy: 0.7902 - mse: 0.1943 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1888 - accuracy: 0.7622 - mse: 0.1888 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1826 - accuracy: 0.7832 - mse: 0.1826 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1856 - accuracy: 0.7622 - mse: 0.1856 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1742 - accuracy: 0.8112 - mse: 0.1742 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1778 - accuracy: 0.7413 - mse: 0.1778 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1825 - accuracy: 0.7413 - mse: 0.1825 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1809 - accuracy: 0.7483 - mse: 0.1809 - lr: 0.0010 - 150ms/epoch - 30ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1704 - accuracy: 0.7902 - mse: 0.1704 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1780 - accuracy: 0.7622 - mse: 0.1780 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1693 - accuracy: 0.7832 - mse: 0.1693 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1695 - accuracy: 0.7972 - mse: 0.1695 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1691 - accuracy: 0.7762 - mse: 0.1691 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1652 - accuracy: 0.7762 - mse: 0.1652 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1599 - accuracy: 0.8112 - mse: 0.1599 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1577 - accuracy: 0.8182 - mse: 0.1577 - lr: 1.0000e-05 - 95ms/epoch - 19ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1659 - accuracy: 0.7692 - mse: 0.1659 - lr: 1.0000e-05 - 93ms/epoch - 19ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1630 - accuracy: 0.7762 - mse: 0.1630 - lr: 1.0000e-05 - 90ms/epoch - 18ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1555 - accuracy: 0.7972 - mse: 0.1555 - lr: 1.0000e-05 - 91ms/epoch - 18ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1641 - accuracy: 0.7692 - mse: 0.1641 - lr: 1.0000e-05 - 92ms/epoch - 18ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1607 - accuracy: 0.8112 - mse: 0.1607 - lr: 1.0000e-05 - 89ms/epoch - 18ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1730 - accuracy: 0.7552 - mse: 0.1730 - lr: 1.0000e-05 - 93ms/epoch - 19ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1558 - accuracy: 0.8042 - mse: 0.1558 - lr: 1.0000e-05 - 92ms/epoch - 18ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1614 - accuracy: 0.7902 - mse: 0.1614 - lr: 1.0000e-05 - 91ms/epoch - 18ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1580 - accuracy: 0.8112 - mse: 0.1580 - lr: 1.0000e-05 - 89ms/epoch - 18ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1595 - accuracy: 0.7902 - mse: 0.1595 - lr: 1.0000e-05 - 93ms/epoch - 19ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1610 - accuracy: 0.7552 - mse: 0.1610 - lr: 1.0000e-07 - 90ms/epoch - 18ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1548 - accuracy: 0.8182 - mse: 0.1548 - lr: 1.0000e-07 - 95ms/epoch - 19ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1561 - accuracy: 0.7832 - mse: 0.1561 - lr: 1.0000e-07 - 91ms/epoch - 18ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1685 - accuracy: 0.7622 - mse: 0.1685 - lr: 1.0000e-07 - 89ms/epoch - 18ms/step
# 2/2 [==============================] - 1s 8ms/step - loss: 0.2068 - accuracy: 0.5556 - mse: 0.2068
# 2/2 [==============================] - 0s 6ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_6\assets
# INFO:tensorflow:Assets written to: LSTM_6\assets
# Accuracy: 0.5556
# Loss: 0.20682193338871002
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 32)                16000
#
#  dense_20 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 16,066
# Trainable params: 16,066
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 3s - loss: 0.2817 - accuracy: 0.5278 - mse: 0.2817 - lr: 0.0010 - 3s/epoch - 622ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.2563 - accuracy: 0.5694 - mse: 0.2563 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.2452 - accuracy: 0.5764 - mse: 0.2452 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.2458 - accuracy: 0.5694 - mse: 0.2458 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.2275 - accuracy: 0.6181 - mse: 0.2275 - lr: 0.0010 - 184ms/epoch - 37ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.2342 - accuracy: 0.5833 - mse: 0.2342 - lr: 0.0010 - 120ms/epoch - 24ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.2277 - accuracy: 0.6319 - mse: 0.2277 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.2243 - accuracy: 0.6528 - mse: 0.2243 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.2202 - accuracy: 0.6389 - mse: 0.2202 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.2221 - accuracy: 0.6528 - mse: 0.2221 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.2171 - accuracy: 0.6597 - mse: 0.2171 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.2099 - accuracy: 0.6736 - mse: 0.2099 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.2080 - accuracy: 0.6736 - mse: 0.2080 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.2040 - accuracy: 0.6736 - mse: 0.2040 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.2050 - accuracy: 0.7153 - mse: 0.2050 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.2082 - accuracy: 0.6458 - mse: 0.2082 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.2025 - accuracy: 0.6875 - mse: 0.2025 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.2044 - accuracy: 0.7153 - mse: 0.2044 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.1985 - accuracy: 0.7292 - mse: 0.1985 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1870 - accuracy: 0.7500 - mse: 0.1870 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1915 - accuracy: 0.7083 - mse: 0.1915 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1786 - accuracy: 0.7431 - mse: 0.1786 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1846 - accuracy: 0.7361 - mse: 0.1846 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1767 - accuracy: 0.7708 - mse: 0.1767 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1758 - accuracy: 0.7569 - mse: 0.1758 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1825 - accuracy: 0.7361 - mse: 0.1825 - lr: 0.0010 - 149ms/epoch - 30ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1722 - accuracy: 0.7778 - mse: 0.1722 - lr: 0.0010 - 111ms/epoch - 22ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1763 - accuracy: 0.7431 - mse: 0.1763 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1722 - accuracy: 0.7708 - mse: 0.1722 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1756 - accuracy: 0.7569 - mse: 0.1756 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1685 - accuracy: 0.7500 - mse: 0.1685 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1563 - accuracy: 0.7986 - mse: 0.1563 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1622 - accuracy: 0.7917 - mse: 0.1622 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1645 - accuracy: 0.7708 - mse: 0.1645 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1594 - accuracy: 0.7917 - mse: 0.1594 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1666 - accuracy: 0.7500 - mse: 0.1666 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1529 - accuracy: 0.8194 - mse: 0.1529 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1497 - accuracy: 0.7986 - mse: 0.1497 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1573 - accuracy: 0.7569 - mse: 0.1573 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1575 - accuracy: 0.7500 - mse: 0.1575 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1596 - accuracy: 0.7708 - mse: 0.1596 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1614 - accuracy: 0.7778 - mse: 0.1614 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1546 - accuracy: 0.7847 - mse: 0.1546 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1588 - accuracy: 0.7778 - mse: 0.1588 - lr: 0.0010 - 104ms/epoch - 21ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1478 - accuracy: 0.8125 - mse: 0.1478 - lr: 0.0010 - 105ms/epoch - 21ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1470 - accuracy: 0.7917 - mse: 0.1470 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1568 - accuracy: 0.7778 - mse: 0.1568 - lr: 0.0010 - 107ms/epoch - 21ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1380 - accuracy: 0.8125 - mse: 0.1380 - lr: 1.0000e-05 - 99ms/epoch - 20ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1507 - accuracy: 0.7917 - mse: 0.1507 - lr: 1.0000e-05 - 98ms/epoch - 20ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1429 - accuracy: 0.8403 - mse: 0.1429 - lr: 1.0000e-05 - 98ms/epoch - 20ms/step
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2677 - accuracy: 0.5278 - mse: 0.2677
# 2/2 [==============================] - 0s 4ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_6\assets
# INFO:tensorflow:Assets written to: LSTM_6\assets
# Accuracy: 0.5278
# Loss: 0.2676906883716583
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 32)                16000
#
#  dense_21 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 16,066
# Trainable params: 16,066
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 3s - loss: 0.2710 - accuracy: 0.5278 - mse: 0.2710 - lr: 0.0010 - 3s/epoch - 622ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.2630 - accuracy: 0.5000 - mse: 0.2630 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.2526 - accuracy: 0.5417 - mse: 0.2526 - lr: 0.0010 - 103ms/epoch - 21ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.2487 - accuracy: 0.5903 - mse: 0.2487 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.2486 - accuracy: 0.5486 - mse: 0.2486 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.2402 - accuracy: 0.5972 - mse: 0.2402 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.2373 - accuracy: 0.5972 - mse: 0.2373 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.2296 - accuracy: 0.6389 - mse: 0.2296 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.2343 - accuracy: 0.5694 - mse: 0.2343 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.2374 - accuracy: 0.5694 - mse: 0.2374 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.2277 - accuracy: 0.6319 - mse: 0.2277 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.2311 - accuracy: 0.5903 - mse: 0.2311 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.2272 - accuracy: 0.5972 - mse: 0.2272 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.2284 - accuracy: 0.6528 - mse: 0.2284 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.2244 - accuracy: 0.6667 - mse: 0.2244 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.2205 - accuracy: 0.6736 - mse: 0.2205 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.2169 - accuracy: 0.6667 - mse: 0.2169 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.2182 - accuracy: 0.6736 - mse: 0.2182 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.2106 - accuracy: 0.7361 - mse: 0.2106 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.2162 - accuracy: 0.6458 - mse: 0.2162 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.2177 - accuracy: 0.6736 - mse: 0.2177 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.2085 - accuracy: 0.6597 - mse: 0.2085 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.2046 - accuracy: 0.7083 - mse: 0.2046 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.2046 - accuracy: 0.6806 - mse: 0.2046 - lr: 0.0010 - 152ms/epoch - 30ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.2065 - accuracy: 0.7153 - mse: 0.2065 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.2018 - accuracy: 0.6944 - mse: 0.2018 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1996 - accuracy: 0.7153 - mse: 0.1996 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1963 - accuracy: 0.7361 - mse: 0.1963 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1921 - accuracy: 0.7569 - mse: 0.1921 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.2091 - accuracy: 0.6667 - mse: 0.2091 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1950 - accuracy: 0.7500 - mse: 0.1950 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.2109 - accuracy: 0.6806 - mse: 0.2109 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.2013 - accuracy: 0.7222 - mse: 0.2013 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1904 - accuracy: 0.7292 - mse: 0.1904 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1910 - accuracy: 0.7500 - mse: 0.1910 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1895 - accuracy: 0.7014 - mse: 0.1895 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1911 - accuracy: 0.7083 - mse: 0.1911 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1844 - accuracy: 0.7361 - mse: 0.1844 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1810 - accuracy: 0.7500 - mse: 0.1810 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1959 - accuracy: 0.7153 - mse: 0.1959 - lr: 1.0000e-05 - 104ms/epoch - 21ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1901 - accuracy: 0.7500 - mse: 0.1901 - lr: 1.0000e-05 - 98ms/epoch - 20ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1695 - accuracy: 0.7569 - mse: 0.1695 - lr: 1.0000e-05 - 94ms/epoch - 19ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1818 - accuracy: 0.7500 - mse: 0.1818 - lr: 1.0000e-05 - 98ms/epoch - 20ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1754 - accuracy: 0.7569 - mse: 0.1754 - lr: 1.0000e-05 - 97ms/epoch - 19ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1802 - accuracy: 0.7708 - mse: 0.1802 - lr: 1.0000e-05 - 94ms/epoch - 19ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1873 - accuracy: 0.7153 - mse: 0.1873 - lr: 1.0000e-05 - 96ms/epoch - 19ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1882 - accuracy: 0.7222 - mse: 0.1882 - lr: 1.0000e-05 - 92ms/epoch - 18ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1832 - accuracy: 0.7431 - mse: 0.1832 - lr: 1.0000e-05 - 96ms/epoch - 19ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1824 - accuracy: 0.7431 - mse: 0.1824 - lr: 1.0000e-05 - 102ms/epoch - 20ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1881 - accuracy: 0.7292 - mse: 0.1881 - lr: 1.0000e-05 - 99ms/epoch - 20ms/step
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1896 - accuracy: 0.6944 - mse: 0.1896
# 2/2 [==============================] - 0s 5ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_6\assets
# INFO:tensorflow:Assets written to: LSTM_6\assets
# Accuracy: 0.6944
# Loss: 0.1895517110824585
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 32)                16000
#
#  dense_22 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 16,066
# Trainable params: 16,066
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 3s - loss: 0.2626 - accuracy: 0.5208 - mse: 0.2626 - lr: 0.0010 - 3s/epoch - 608ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.2489 - accuracy: 0.5694 - mse: 0.2489 - lr: 0.0010 - 90ms/epoch - 18ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.2446 - accuracy: 0.5486 - mse: 0.2446 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.2418 - accuracy: 0.5764 - mse: 0.2418 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.2388 - accuracy: 0.5625 - mse: 0.2388 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.2353 - accuracy: 0.5903 - mse: 0.2353 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.2348 - accuracy: 0.6528 - mse: 0.2348 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.2158 - accuracy: 0.6875 - mse: 0.2158 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.2251 - accuracy: 0.6667 - mse: 0.2251 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.2265 - accuracy: 0.6389 - mse: 0.2265 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.2139 - accuracy: 0.7153 - mse: 0.2139 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.2102 - accuracy: 0.7014 - mse: 0.2102 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.2101 - accuracy: 0.6944 - mse: 0.2101 - lr: 0.0010 - 92ms/epoch - 18ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.2120 - accuracy: 0.6597 - mse: 0.2120 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.2062 - accuracy: 0.6736 - mse: 0.2062 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.1997 - accuracy: 0.7431 - mse: 0.1997 - lr: 0.0010 - 105ms/epoch - 21ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.1976 - accuracy: 0.7153 - mse: 0.1976 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.1859 - accuracy: 0.7847 - mse: 0.1859 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.1862 - accuracy: 0.7500 - mse: 0.1862 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1905 - accuracy: 0.7569 - mse: 0.1905 - lr: 0.0010 - 99ms/epoch - 20ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1887 - accuracy: 0.7361 - mse: 0.1887 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1903 - accuracy: 0.7361 - mse: 0.1903 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1880 - accuracy: 0.7708 - mse: 0.1880 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1862 - accuracy: 0.7431 - mse: 0.1862 - lr: 0.0010 - 100ms/epoch - 20ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1853 - accuracy: 0.7569 - mse: 0.1853 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1814 - accuracy: 0.7569 - mse: 0.1814 - lr: 0.0010 - 104ms/epoch - 21ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1689 - accuracy: 0.7431 - mse: 0.1689 - lr: 0.0010 - 103ms/epoch - 21ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1651 - accuracy: 0.7778 - mse: 0.1651 - lr: 0.0010 - 159ms/epoch - 32ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1803 - accuracy: 0.7500 - mse: 0.1803 - lr: 1.0000e-05 - 100ms/epoch - 20ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1703 - accuracy: 0.7569 - mse: 0.1703 - lr: 1.0000e-05 - 99ms/epoch - 20ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1788 - accuracy: 0.7500 - mse: 0.1788 - lr: 1.0000e-05 - 96ms/epoch - 19ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1828 - accuracy: 0.7153 - mse: 0.1828 - lr: 1.0000e-05 - 101ms/epoch - 20ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1847 - accuracy: 0.7153 - mse: 0.1847 - lr: 1.0000e-05 - 100ms/epoch - 20ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1732 - accuracy: 0.7431 - mse: 0.1732 - lr: 1.0000e-05 - 103ms/epoch - 21ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1803 - accuracy: 0.7083 - mse: 0.1803 - lr: 1.0000e-05 - 100ms/epoch - 20ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1736 - accuracy: 0.7083 - mse: 0.1736 - lr: 1.0000e-05 - 97ms/epoch - 19ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1890 - accuracy: 0.7014 - mse: 0.1890 - lr: 1.0000e-05 - 97ms/epoch - 19ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1708 - accuracy: 0.7292 - mse: 0.1708 - lr: 1.0000e-05 - 91ms/epoch - 18ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1758 - accuracy: 0.7778 - mse: 0.1758 - lr: 1.0000e-07 - 92ms/epoch - 18ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1716 - accuracy: 0.7847 - mse: 0.1716 - lr: 1.0000e-07 - 92ms/epoch - 18ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1839 - accuracy: 0.7361 - mse: 0.1839 - lr: 1.0000e-07 - 94ms/epoch - 19ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1775 - accuracy: 0.7361 - mse: 0.1775 - lr: 1.0000e-07 - 95ms/epoch - 19ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1847 - accuracy: 0.6875 - mse: 0.1847 - lr: 1.0000e-07 - 91ms/epoch - 18ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1823 - accuracy: 0.7361 - mse: 0.1823 - lr: 1.0000e-07 - 131ms/epoch - 26ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1745 - accuracy: 0.7292 - mse: 0.1745 - lr: 1.0000e-07 - 142ms/epoch - 28ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1784 - accuracy: 0.7917 - mse: 0.1784 - lr: 1.0000e-07 - 109ms/epoch - 22ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1734 - accuracy: 0.7569 - mse: 0.1734 - lr: 1.0000e-07 - 93ms/epoch - 19ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1776 - accuracy: 0.7431 - mse: 0.1776 - lr: 1.0000e-07 - 94ms/epoch - 19ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1744 - accuracy: 0.7500 - mse: 0.1744 - lr: 1.0000e-07 - 92ms/epoch - 18ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1674 - accuracy: 0.7639 - mse: 0.1674 - lr: 1.0000e-07 - 96ms/epoch - 19ms/step
# 2/2 [==============================] - 1s 8ms/step - loss: 0.1739 - accuracy: 0.8333 - mse: 0.1739
# 2/2 [==============================] - 0s 5ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_6\assets
# INFO:tensorflow:Assets written to: LSTM_6\assets
# Accuracy: 0.8333
# Loss: 0.17387142777442932
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_23 (LSTM)              (None, 32)                16000
#
#  dense_23 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 16,066
# Trainable params: 16,066
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 3s - loss: 0.2712 - accuracy: 0.5139 - mse: 0.2712 - lr: 0.0010 - 3s/epoch - 608ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.2594 - accuracy: 0.5556 - mse: 0.2594 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.2427 - accuracy: 0.5903 - mse: 0.2427 - lr: 0.0010 - 106ms/epoch - 21ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.2511 - accuracy: 0.5764 - mse: 0.2511 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.2470 - accuracy: 0.5694 - mse: 0.2470 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.2463 - accuracy: 0.5833 - mse: 0.2463 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.2455 - accuracy: 0.5625 - mse: 0.2455 - lr: 0.0010 - 102ms/epoch - 20ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.2376 - accuracy: 0.5903 - mse: 0.2376 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.2345 - accuracy: 0.5833 - mse: 0.2345 - lr: 0.0010 - 88ms/epoch - 18ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.2357 - accuracy: 0.6250 - mse: 0.2357 - lr: 0.0010 - 92ms/epoch - 18ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.2320 - accuracy: 0.6389 - mse: 0.2320 - lr: 0.0010 - 91ms/epoch - 18ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.2320 - accuracy: 0.6458 - mse: 0.2320 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.2274 - accuracy: 0.6458 - mse: 0.2274 - lr: 0.0010 - 90ms/epoch - 18ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.2279 - accuracy: 0.6528 - mse: 0.2279 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.2227 - accuracy: 0.6319 - mse: 0.2227 - lr: 0.0010 - 92ms/epoch - 18ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.2205 - accuracy: 0.6597 - mse: 0.2205 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.2222 - accuracy: 0.6806 - mse: 0.2222 - lr: 0.0010 - 101ms/epoch - 20ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.2122 - accuracy: 0.6667 - mse: 0.2122 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.2124 - accuracy: 0.7222 - mse: 0.2124 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.2224 - accuracy: 0.6319 - mse: 0.2224 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.2148 - accuracy: 0.6458 - mse: 0.2148 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.2137 - accuracy: 0.6458 - mse: 0.2137 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.2106 - accuracy: 0.6806 - mse: 0.2106 - lr: 0.0010 - 89ms/epoch - 18ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.2154 - accuracy: 0.6736 - mse: 0.2154 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.2056 - accuracy: 0.7292 - mse: 0.2056 - lr: 0.0010 - 89ms/epoch - 18ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.2033 - accuracy: 0.6528 - mse: 0.2033 - lr: 0.0010 - 88ms/epoch - 18ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.2034 - accuracy: 0.7222 - mse: 0.2034 - lr: 0.0010 - 91ms/epoch - 18ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.2045 - accuracy: 0.6944 - mse: 0.2045 - lr: 0.0010 - 142ms/epoch - 28ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.2007 - accuracy: 0.7014 - mse: 0.2007 - lr: 0.0010 - 96ms/epoch - 19ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.2018 - accuracy: 0.7083 - mse: 0.2018 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.2008 - accuracy: 0.6667 - mse: 0.2008 - lr: 0.0010 - 91ms/epoch - 18ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1976 - accuracy: 0.7153 - mse: 0.1976 - lr: 0.0010 - 174ms/epoch - 35ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1894 - accuracy: 0.7153 - mse: 0.1894 - lr: 0.0010 - 112ms/epoch - 22ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1926 - accuracy: 0.7222 - mse: 0.1926 - lr: 0.0010 - 91ms/epoch - 18ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1864 - accuracy: 0.7361 - mse: 0.1864 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1895 - accuracy: 0.7222 - mse: 0.1895 - lr: 0.0010 - 94ms/epoch - 19ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1825 - accuracy: 0.7361 - mse: 0.1825 - lr: 0.0010 - 91ms/epoch - 18ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1818 - accuracy: 0.7500 - mse: 0.1818 - lr: 0.0010 - 91ms/epoch - 18ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1948 - accuracy: 0.7431 - mse: 0.1948 - lr: 0.0010 - 97ms/epoch - 19ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1798 - accuracy: 0.7639 - mse: 0.1798 - lr: 0.0010 - 98ms/epoch - 20ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1886 - accuracy: 0.7361 - mse: 0.1886 - lr: 0.0010 - 91ms/epoch - 18ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1775 - accuracy: 0.7292 - mse: 0.1775 - lr: 0.0010 - 90ms/epoch - 18ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1813 - accuracy: 0.7083 - mse: 0.1813 - lr: 0.0010 - 95ms/epoch - 19ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1906 - accuracy: 0.7292 - mse: 0.1906 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1733 - accuracy: 0.7500 - mse: 0.1733 - lr: 0.0010 - 90ms/epoch - 18ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1801 - accuracy: 0.7431 - mse: 0.1801 - lr: 0.0010 - 93ms/epoch - 19ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1814 - accuracy: 0.7083 - mse: 0.1814 - lr: 0.0010 - 88ms/epoch - 18ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1800 - accuracy: 0.7292 - mse: 0.1800 - lr: 0.0010 - 92ms/epoch - 18ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1733 - accuracy: 0.7639 - mse: 0.1733 - lr: 0.0010 - 91ms/epoch - 18ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1671 - accuracy: 0.7986 - mse: 0.1671 - lr: 0.0010 - 89ms/epoch - 18ms/step
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1980 - accuracy: 0.7500 - mse: 0.1980
# 2/2 [==============================] - 0s 5ms/step
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_6\assets
# INFO:tensorflow:Assets written to: LSTM_6\assets
# Accuracy: 0.75
# Loss: 0.1980392336845398

# %%
results = pd.DataFrame(data = [results_2012[:2],results_2013[:2],results_2014[:2],results_2015[:2],results_2016[:2],
                               results_2017[:2],results_2018[:2],results_2019[:2]],
                            index = ['2012', '2013', '2014','2015','2016','2017','2018','2019'],
                            columns = ['loss', 'accuracy'])
sum(results['accuracy'])/8
# Out:
# 0.65625

# %%
def build_conf_matrix(prediction, true):
    s = 0
    pl = []
    for pred in prediction:
        if pred[0] > pred[1]:
            pl.append(0)
        else:
            pl.append(1)

    for i in range(len(pl)):
        if pl[i] == true.values[i]:
            s+=1

    c_train = confusion_matrix(true, pl)
    disp = ConfusionMatrixDisplay(c_train)
    return disp

cf_2012 = build_conf_matrix(pred_2012, y_valid_2012)
cf_2013 = build_conf_matrix(pred_2013, y_valid_2013)
cf_2014 = build_conf_matrix(pred_2014, y_valid_2014)
cf_2015 = build_conf_matrix(pred_2015, y_valid_2015)
cf_2016 = build_conf_matrix(pred_2016, y_valid_2016)
cf_2017 = build_conf_matrix(pred_2017, y_valid_2017)
cf_2018 = build_conf_matrix(pred_2018, y_valid_2018)
cf_2019 = build_conf_matrix(pred_2019, y_valid_2019)


fig, ax = plt.subplots(3,3)
fig.set_figwidth(10)
fig.set_figheight(12)
fig.suptitle("Confusion Matrices: LSTM Model 6 Training/Validation Set 65.6%")
cf_2012.plot(ax=ax[0][0]), cf_2013.plot(ax=ax[0][1]), cf_2014.plot(ax=ax[0][2])
cf_2015.plot(ax=ax[1][0]), cf_2016.plot(ax=ax[1][1]), cf_2017.plot(ax=ax[1][2])
cf_2018.plot(ax=ax[2][0]), cf_2019.plot(ax=ax[2][1])

ax[0][0].set_title(2012), ax[0][1].set_title(2013), ax[0][2].set_title(2014)
ax[1][0].set_title(2015), ax[1][1].set_title(2016), ax[1][2].set_title(2017)
ax[2][0].set_title(2018), ax[2][1].set_title(2019)
# Out:
# (Text(0.5, 1.0, '2018'), Text(0.5, 1.0, '2019'))

# %% [markdown]
# Res_1 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.25, recurrent_dropout = 0.25, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_2 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'sigmoid' , dropout = 0.25, recurrent_dropout = 0.25, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_3 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.25, recurrent_dropout = 0.25, return_sequences=True))
#     model.add(LSTM( 64, activation='tanh ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_4 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.2, recurrent_dropout = 0.2, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_5 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
#
# Res_6 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.4, recurrent_dropout = 0.4, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(2, activation="tanh"))
#
# Res_7 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3, return_sequences=True))
#     model.add(LSTM( 64, return_sequences=True))
#     model.add(LSTM( 64 ))
#     model.add(Dense(64, activation="tanh))
#     model.add(Dense(2, activation="tanh"))
#
# Res_8 =   model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3, return_sequences=True))
#     model.add(LSTM( 64, return_sequences=True, dropout = 0.3))
#     model.add(LSTM( 64 ))
#     model.add(Dense(32, activation="tanh))
#     model.add(Dense(2, activation="tanh"))
#
# Res_10 = model.add(LSTM( 128 ,input_shape = (88,1), activation = 'tanh' , dropout = 0.3, recurrent_dropout = 0.3, return_sequences=True))
#     model.add(LSTM( 64, return_sequences=True, dropout=0.3))
#     model.add(LSTM( 32, return_sequences=True, dropout= .1 ))
#     model.add(LSTM( 16, return_sequences=True ))
#     model.add(Dense(8))
#     model.add(LSTM( 32 ))
#     # model.add(LSTM( 64 ))
#     model.add(Dense(32, activation="tanh"))
#     model.add(Dense(16, activation="tanh"))
#     model.add(Dense(2, activation="tanh"))

# %%
loss = train_history.history['loss']
# validation_loss = train_history.history['val_loss']
accuracy = train_history.history['accuracy']
# val_accuracy = train_history.history['val_accuracy']

fig = plt.gcf()
fig.set_size_inches(18.5, 5.5)
plt.subplot(1,2,1)
plt.plot(loss)
plt.plot(validation_loss)
plt.legend(['loss', 'validation_loss'])
plt.subplot(1,2,2)
plt.plot(accuracy)
plt.plot(val_accuracy)
plt.legend(['accuracy', 'validation_accuracy'])
plt.show()
